# %% [markdown]
# **Authors**: Firas Abouzahr (Northwestern), Sara Sussman (Fermilab)

# %% [markdown]
# # Background reading on CEM for cQED
# The computational-electromagnetics (CEM) methods underlying these simulations — FEM discretization, meshing, eigenvalue solvers, and the multiscale challenges specific to superconducting devices — are reviewed in:
# * [Elkin et al.](https://arxiv.org/abs/2511.20774), *Opportunities and Challenges of Computational Electromagnetics Methods for Superconducting Circuit Quantum Device Modeling: A Practical Review*, arXiv:2511.20774 (2025).
#
# We point to specific sections of this review inline below.

# %% [markdown]
# # A Brief Introduction to pyPalace
# [pyPalace](https://pypalace.readthedocs.io/en/latest/) is an open-source Python toolkit for simulating and analyzing superconducting quantum devices with AWS Palace.
#
# [SQDMetal](https://github.com/sqdlab/SQDMetal) and pyPalace are complementary tools in this workshop series: SQDMetal provides an integrated Metal-to-Palace workflow in the quantum-device-design track, while **pyPalace exposes Palace's native configuration directly in Python** — the `Problems`, `Model`, `Domains`, `Boundaries`, and `Solver` blocks you build map one-to-one to what Palace expects on disk. If you already know Palace's config format, you are not learning a second abstraction—you are assembling the same files, with less boilerplate.
#
# This notebook follows [Example 01 (eigenmode + EPR)](https://github.com/FirasAbouzahr/pyPalace/tree/main/Examples/example_01_eigenmode_EPR) in the pyPalace repository.
#
# ### What pyPalace helps you do:
# * **Build** Palace configuration files from Python (Config + builder helpers)
# * **Run** electrostatic, magnetostatic, eigenmode, and driven (time- or frequency-domain) simulations locally (mpirun) or on HPC (Slurm)
# * **Extract standard outputs** (capacitance matrices, eigenfrequencies, S-parameters, fields)
# * **Analyze superconducting circuits** with quantum-oriented utilities such as Lumped Oscillator Modeling (LOM) and Energy Participation Ratio (EPR)
#
# ### Meshing and design workflows
# pyPalace does not lock you into one design toolchain.
# * **Quantum Metal → mesh (built-in path):** Example workflows show how to take a Quantum Metal planar layout and mesh it with pyPalace's built-in meshing utilities (Gmsh-based), including physical groups for terminals and materials that Palace needs.
# * **Any other meshed design:** Palace accepts a wide range of mesh formats (e.g. Gmsh .msh, Nastran .bdf, and others). You can mesh in Gmsh, Cubit, COMSOL export, or any tool that produces a Palace-compatible mesh—then point `config["Model"]["Mesh"]` at that file and build boundaries from the mesh attribute table.
# So the mesh source is flexible; pyPalace's job is to connect your mesh + Palace config + solver run + analysis in Python.
#
# ### Typical workflow
# 1. Obtain or generate a mesh (Quantum Metal + pyPalace meshing, or an external mesher)
# 2. Build a Palace config in Python (materials, terminals, solver settings)
# 3. Run Palace through Simulation
# 4. Extract Hamiltonian or circuit parameters with LOM, EPR, or related analysis tools
#
# ### pyPalace resources
# * [GitHub Homepage](https://github.com/FirasAbouzahr/pyPalace)
# * [Documentation](https://pypalace.readthedocs.io/en/latest/)
# * [end-to-end Examples](https://github.com/FirasAbouzahr/pyPalace/tree/main/Examples)
#
# ### <u>Before we start</u>
# The shared workshop environment includes Palace and `mpirun`. We use `pypalace.palace_env.get_palace_executable()` to locate the Palace binary automatically. You will also need Python 3.9+ (3.11+ in the shared Docker image).
#
# ### <u>Contributing to pyPalace</u>
# pyPalace is a community-driven project with a small maintainer team. The goal is a design- and mesh-agnostic Python layer for automating electromagnetic workflows. Issues, PRs, and feedback are welcome on [GitHub](https://github.com/FirasAbouzahr/pyPalace). For collaboration, contact [Firas Abouzahr](mailto:firasabouzahr2030@u.northwestern.edu).

# %% [markdown]
# # Eigenmode simulations for superconducting circuits

# %% [markdown]
# ## What are eigenmode simulations?
#
# Eigenmode simulations solve the source-free electromagnetic wave equation. For nonmagnetic media ($\mu_r = 1$, as assumed throughout for these dielectrics and superconductors) this reads
#
# $$\nabla \times (\nabla \times \mathbf{E}) - \epsilon_r\left(\frac{\omega}{c}\right)^2\mathbf{E} = 0,$$
#
# which is the source-free limit of the general curl–curl form $\nabla \times \mu_r^{-1}\nabla \times \mathbf{E} = k_0^2\,\epsilon_r\,\mathbf{E}$ ($k_0 = \omega/c$ is the free-space wavenumber); see [Elkin et al., arXiv:2511.20774 (2025)](https://arxiv.org/abs/2511.20774), Eq. (33).
#
#
# Palace is an open-source Finite Element Method (FEM) solver that performs complex physics simulations on digitized objects. To do this, a process called meshing first divides the complex geometric model into a network of small, simple shapes called elements. Palace then solves the physics equations piece by piece across this network to calculate how the whole structure will behave. In this light, more accurately, Palace solves the *discretized* version of the source-free electromagnetic wave equation (see the [Palace documentation](https://awslabs.github.io/palace/stable/reference/#Eigenmode-calculations)). In current practice, FEM is the standard CEM method used for cQED device modeling ([Elkin et al., arXiv:2511.20774 (2025)](https://arxiv.org/abs/2511.20774), Sec. III F).
#
#
# ## Why eigenmode simulations?
# Eigenmode simulations determine the natural resonant frequencies and electromagnetic field distributions supported by a structure. In other words, they identify the standing-wave modes that can exist without an external drive.
#
# For superconducting circuits, eigenmode simulations are used to extract resonant frequencies, mode shapes, and quality factors. The resulting electric and magnetic field distributions can then be used in Energy Participation Ratio (EPR) analysis, which quantifies how electromagnetic energy is distributed throughout the device. These participation ratios are subsequently used to extract Hamiltonian parameters such as qubit anharmonicity ($\alpha$) and the resonator dispersive shift ($\chi$).

# %% [markdown]
# # Eigenmode simulation and EPR analysis of transmon-resonator system

# %% [markdown]
# ## Coupled transmon-resonator device
#
# For this tutorial, we will be using the coupled transmon-resonator device layout from the ``quantum-device-design`` led by Murat, specifically we'll use the design from [`03_transmon_and_resonator.ipynb`](https://github.com/quantum-device-consortium/qdw26-workshop-materials/blob/main/workshops/quantum-device-design/notebooks/03_transmon_and_resonator.ipynb).

# %%
# Run Quantum Metal headless so the notebook renders inline and never needs a
# display (works in JupyterLab, Docker, CI, or any headless machine). These are
# set with setdefault, so the container's own settings still take precedence.
import os
os.environ.setdefault("QISKIT_METAL_HEADLESS", "1")
os.environ.setdefault("QT_QPA_PLATFORM", "offscreen")
os.environ.setdefault("MPLBACKEND", "Agg")

import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import Dict, Headings
from qiskit_metal import MetalGUI

from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond

from SQDMetal.Comps.Xmon import Xmon
from SQDMetal.Comps.Junctions import JunctionDolanPinStretch
from SQDMetal.Comps.Capacitors import CapacitorProngPin
from SQDMetal.Utilities.Materials import MaterialInterface

# %%
design = designs.DesignPlanar({}, overwrite_enabled=True)
design.delete_all_components()
gui = MetalGUI(design)

um = 1e-3 # default units of Quantum Metal are in mm, so we get um by multiplying by 1e-3

# Set up chip dimensions 
design.chips.main.size.size_x = '3.5mm'
design.chips.main.size.size_y = '3mm'
design.chips.main.size.size_z = '-280um'
design.chips.main.size.center_x = '0mm'
design.chips.main.size.center_y = '-1mm'

# Resonator and feedline gap width (W) and center conductor width (S) 
design.variables['cpw_width'] = '8 um' #S
design.variables['cpw_gap'] = '4 um' #W 
# Lets create the qubit with a junction and a claw

## Qubit
xmon = Xmon(design, 'xmon', options=Dict(pos_x = '0mm', pos_y='-1.6',
                                    vBar_width='50um', hBar_width='50um', vBar_gap=f'{50}um', hBar_gap=f'{50}um',
                                    cross_width=f'{320}um', cross_height=f'{320}um',
                                    gap_up='40um', gap_left='40um', gap_right='40um', gap_down='40um'))

# # Claw
CapacitorProngPin(design, 'claw', options=Dict(pin_inputs=Dict(start_pin=Dict(component=f'xmon',pin='up')),
                                                prong_width='10um', prong_length='20um', pin_gap_side='10um',
                                                gap_side='20um', pad_thickness='20um',
                                                gap_front='20um', gap_back='20um', trace_width='10um'))

# Lauchpad 1
x1 = '-1.2mm'
y1 = '0mm'
launch_options1 = dict(chip='main', pos_x=x1, pos_y=y1, orientation='360', lead_length='30um', pad_height='103um', 
                      pad_width='103um', pad_gap='60um')
LP1 = LaunchpadWirebond(design, 'LP1', options = launch_options1)

# Launchpad 2
x2 = '1.2mm'
y1 = '0mm'
launch_options2 = dict(chip='main', pos_x=x2, pos_y=y1, orientation='180', lead_length='30um', pad_height='103um', 
                      pad_width='103um', pad_gap='60um')
LP2 = LaunchpadWirebond(design, 'LP2', options = launch_options2)

# Using path finder to connect the two launchpads
feedline = RoutePathfinder(design, 'feedline', options = dict(chip='main', trace_width ='8um',
                                            trace_gap ='4um',
                                            fillet='200um',                                                            
                                            hfss_wire_bonds = True,
                                            lead=dict(end_straight='0.1mm'),
                                            pin_inputs=Dict(
                                                start_pin=Dict(
                                                    component='LP1',
                                                    pin='tie'),
                                                end_pin=Dict(
                                                    component='LP2',
                                                    pin='tie')
                                            )))
#open to ground for resonator
otg1 = OpenToGround(design, 'otg1', options=dict(chip='main', pos_x='-0.2mm',  pos_y='-40um', orientation = 180, width = '8um', gap='4um',))

# Use RouteMeander to fix the total length of the resonator
res1 = RouteMeander(design, 'resonator',  Dict(
        trace_width ='8um',
        trace_gap ='4um',
        total_length='8.6mm',
        hfss_wire_bonds = False,
        fillet='100um',
        lead = dict(start_straight='100um'),
        meander = dict(spacing='0.2mm'),
        pin_inputs=Dict(
        start_pin=Dict(component= 'otg1', pin= 'open'),
        end_pin=Dict(component= 'claw', pin= 'a')), ))

## after this we can add our custom components (lumped ports for feedline and junction)
gui.rebuild()

## create a rectangle that we will use as our JJ lumped port --> more on this below
JJ_y2 = float(xmon.options["pos_y"]) - float(xmon.options["cross_height"][:-2])*um/2 ## do some simple algebra to place it appropriately on the xmon
JJ_y1 = JJ_y2 - float(xmon.options["gap_down"][:-2])*um
JJ_y = (JJ_y1 + JJ_y2)/2
JJ_length = abs(JJ_y2-JJ_y1)
JJ_width = 5.4*um
JJ_geometry = draw.rectangle(JJ_width,JJ_length,0,JJ_y)
design.qgeometry.add_qgeometry("poly",xmon.id,{"josephson_junction": JJ_geometry},layer=1,subtract=False)

res_options = res1.options
LP1_options = LP1.options
port1_x = (float(LP1_options["pos_x"][:-2]) 
         - (float(LP1_options["pad_width"][:-2]) 
         + float(LP1_options["taper_height"][:-2])) * um 
         - float(LP1_options["pad_gap"][:-2])/2 * um)
port1_y = float(LP1_options["pos_y"][:-2])
port1_width = float(LP1_options["pad_gap"][:-2])*um
port1_length = float(LP1_options["pad_height"][:-2])*um
feedline_port1 = draw.rectangle(port1_width,port1_length, port1_x, port1_y)
design.qgeometry.add_qgeometry("poly",LP1.id,{"feedline_port1": feedline_port1},layer=1,subtract=False)

LP2_options = LP2.options
port2_x = (float(LP2_options["pos_x"][:-2]) 
         + (float(LP2_options["pad_width"][:-2]) 
         + float(LP2_options["taper_height"][:-2])) * um 
         + float(LP2_options["pad_gap"][:-2])/2 * um)
port2_y = float(LP2_options["pos_y"][:-2])
port2_width = float(LP2_options["pad_gap"][:-2])*um
port2_length = float(LP2_options["pad_height"][:-2])*um
feedline_port2 = draw.rectangle(port2_width,port2_length, port2_x, port2_y)
design.qgeometry.add_qgeometry("poly",LP2.id,{"feedline_port2": feedline_port2},layer=1,subtract=False)

# rebuild the GUI
gui.refresh()
gui.autoscale()
# Out:
# 10:41PM 26s WARNING [_qt_message_handler]: WARNING: Populating font family aliases took 57 ms. Replace uses of missing font family "Sans Serif" with one that exists to avoid this cost.  (No context available from Qt)
# Python Traceback (most recent call last):
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3225, in _run_cell
#     result = runner(coro)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3447, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3688, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3748, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/2s/nr5g4p5s7b1_60_1dgnpfymw0000gn/T/ipykernel_77760/3133529976.py", line 3, in <module>
#     gui = MetalGUI(design)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/main_window.py", line 354, in __init__
#     super().__init__()
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/main_window_base.py", line 331, in __init__
#     self.ui.setupUi(self.main_window)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/main_window_ui.py", line 53, in setupUi
#     self.tabWidget.addTab(self.mainViewTab, icon1, "")
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/utility/_handle_qt_messages.py", line 83, in _qt_message_handler
#     python_traceback = "".join(traceback.format_stack(limit=10))
#
# 10:41PM 26s WARNING [_qt_message_handler]: WARNING: This plugin does not support propagateSizeHints() (No context available from Qt)
# Python Traceback (most recent call last):
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3170, in run_cell
#     result = self._run_cell(
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3225, in _run_cell
#     result = runner(coro)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3447, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3688, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3748, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/2s/nr5g4p5s7b1_60_1dgnpfymw0000gn/T/ipykernel_77760/3133529976.py", line 3, in <module>
#     gui = MetalGUI(design)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/main_window.py", line 364, in __init__
#     self.variables_window = PropertyTableWidget(self, gui=self)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/widgets/variable_table/prop_val_table_gui.py", line 54, in __init__
#     self.show()
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/utility/_handle_qt_messages.py", line 83, in _qt_message_handler
#     python_traceback = "".join(traceback.format_stack(limit=10))
#
# 10:41PM 26s WARNING [_qt_message_handler]: WARNING: This plugin does not support propagateSizeHints() (No context available from Qt)
# Python Traceback (most recent call last):
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3170, in run_cell
#     result = self._run_cell(
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3225, in _run_cell
#     result = runner(coro)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3447, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3688, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3748, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/2s/nr5g4p5s7b1_60_1dgnpfymw0000gn/T/ipykernel_77760/3133529976.py", line 3, in <module>
#     gui = MetalGUI(design)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/main_window.py", line 372, in __init__
#     self.main_window.show()
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/utility/_handle_qt_messages.py", line 83, in _qt_message_handler
#     python_traceback = "".join(traceback.format_stack(limit=10))
#
# 10:41PM 26s WARNING [_qt_message_handler]: WARNING: This plugin does not support propagateSizeHints() (No context available from Qt)
# Python Traceback (most recent call last):
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3170, in run_cell
#     result = self._run_cell(
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3225, in _run_cell
#     result = runner(coro)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3447, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3688, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3748, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/2s/nr5g4p5s7b1_60_1dgnpfymw0000gn/T/ipykernel_77760/3133529976.py", line 3, in <module>
#     gui = MetalGUI(design)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/main_window.py", line 373, in __init__
#     self._setup_variables_widget()
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/main_window.py", line 581, in _setup_variables_widget
#     self.ui.dockVariables.setWidget(self.variables_window)
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/utility/_handle_qt_messages.py", line 83, in _qt_message_handler
#     python_traceback = "".join(traceback.format_stack(limit=10))
#
# 10:41PM 26s WARNING [_qt_message_handler]: WARNING: This plugin does not support raise() (No context available from Qt)
# Python Traceback (most recent call last):
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3688, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3748, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/2s/nr5g4p5s7b1_60_1dgnpfymw0000gn/T/ipykernel_77760/3133529976.py", line 112, in <module>
#     gui.autoscale()
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/main_window.py", line 926, in autoscale
#     self.plot_win.auto_scale()
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/widgets/plot_widget/plot_window.py", line 109, in auto_scale
#     self.canvas.auto_scale()
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/renderers/renderer_mpl/mpl_canvas.py", line 600, in auto_scale
#     self.refresh()
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/renderers/renderer_mpl/mpl_canvas.py", line 539, in refresh
#     self.flush_events()
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/matplotlib/backends/backend_qt.py", line 466, in flush_events
#     QtWidgets.QApplication.instance().processEvents()
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/main_window.py", line 393, in _raise
#     self.main_window.raise_()
#   File "/Users/firasabouzahr/miniforge3/envs/QDW26/lib/python3.11/site-packages/qiskit_metal/_gui/utility/_handle_qt_messages.py", line 83, in _qt_message_handler
#     python_traceback = "".join(traceback.format_stack(limit=10))

# %% [markdown]
# ### <u>Modeling junctions</u>
#
# Notice above we did not explicitly add the Josephson junction as was done in the quantum device design workshop. Instead we added a little rectangle in its place. **Why?**
#
# There are two critical points regarding modeling junctions in electromagnetic simulations:
# 1. Junctions are nanometer-scale components, this makes it very hard to mesh them, especially because other meshed components are on the scale of tens to hundreds of microns. Instead we replace the junction geometry with a simple rectangle and define it as a lumped port.
# 2. Junctions are modeled as lumped ports with a *linear* inductance. FEM simulations are inherently classical and most (or all), solvers do not have the ability to assign a port a non-linear inductance.

# %% [markdown]
# # Meshing
#
# Before a simulation can be solved, the geometry must be discretized into a collection of small elements called a **mesh**. Rather than solving Maxwell's equations exactly on a continuous geometry, finite element tools (like Palace) solve them on this discretized representation. In general, a finer mesh provides a more accurate representation of the true geometry, but increases computational cost.
#
# ### <u>Some "Rules of thumb" for meshing</u>
#
# * The initial mesh on resonant structures should have an element size no larger than approximately $\lambda/4$, where $\lambda$ is the wavelength at the frequency of interest. *I've heard plenty of variations of this rule, $\lambda/4$, $\lambda/10$, $\lambda/20$...* For cQED devices, however, the wavelength is usually not what limits the mesh: the relevant features (gaps, junction leads, thin films) are far smaller than the wavelength: the structures are *electrically small*. So, that part of the mesh must be made smaller to accommodate these small features. Since some features are much smaller than others, we end up with a mix of tiny and large elements (making the mesh everywhere tiny would be too slow to solve). This spread of element sizes makes the problem *multiscale*, which ill-conditions the matrix: big and small elements give entries of very different sizes, and since the computer only keeps so many digits, the small ones can get rounded away when mixed with the big ones, leaving the solver without the information it needs to converge ([Elkin et al., arXiv:2511.20774 (2025)](https://arxiv.org/abs/2511.20774), Sec. V C).
# * Finer meshes generally produce more accurate simulations because they better approximate the true device geometry and electromagnetic fields.
# * Mesh refinement should be focused in regions where fields vary rapidly or where geometric details are important (e.g., coupling gaps, junction regions, or generally important circuit components).
# * Coarser meshes can often be used in regions that have little impact on the quantities of interest, reducing simulation time and memory usage.

# %% [markdown]
# # Mesh Quantum Metal design with pyPalace (Gmsh backend)
#
# In Palace, mesh attributes provide the labels used to specify entries in `config["Domains"]` (volume regions or related postprocessing) and `config["Boundaries"]` (surface regions where we apply boundary conditions or related postprocessing).
#
# pyPalace leaves it up to the user to define which Quantum Metal surfaces we want to give mesh attributes for full flexibility. Volumes (substrate & air box), the far field, and the ground plane are automatically assigned mesh attributes. Let's take a look at our Quantum Metal design surfaces table:

# %%
from pypalace import mesh

# %%
surface_table = mesh.get_quantum_metal_surfaces(design)
surface_table
# Out:
#     component_id component_name                name  subtract
# 0              1           xmon               cross     False
# 1              1           xmon                 gap      True
# 2              2           claw                 pad     False
# 3              2           claw              padGap      True
# 4              3            LP1          launch_pad     False
# 5              3            LP1              pocket      True
# 6              4            LP2          launch_pad     False
# 7              4            LP2              pocket      True
# 8              6           otg1      open_to_ground      True
# 9              1           xmon  josephson_junction     False
# 10             3            LP1      feedline_port1     False
# 11             4            LP2      feedline_port2     False
# 12             5       feedline               trace     False
# 13             5       feedline                 cut      True
# 14             7      resonator               trace     False
# 15             7      resonator                 cut      True

# %% [markdown]
# Polygons with `subtract == True` are the designs' metal (superconducting thin-film) components, while polygons with `subtract == False` are etched regions. We will want to give all metal components some boundary condition, so we need to give all of these mesh attributes.
#
# For interface dielectric losses (boundaries postprocessing), we would also want to assign etched regions mesh attributes as well. For this example, we will skip this.

# %%
# each dictionary component has entry component ID, name, mesh attribute ID we want to assign it
attributes = {}

# this loop is simply assigning every metal component in our design a mesh attribute
mesh_num = 1
for row in range(len(surface_table)):
    this_component = surface_table.iloc[row]
    if this_component["subtract"] == False:
        name = this_component["name"]
        comp_id = this_component["component_id"]
        attributes[(comp_id,name)] = mesh_num
        mesh_num += 1 # cannot repeat mesh IDs or Palace will fail


# we will also give attributes to the dielectric gaps of/near to show an example of interface dielectric loss analysis
attributes[(1,'gap')] = mesh_num+1
attributes[(2,'padGap')] = mesh_num+2

attributes # each dictionary entry follows: (<component ID number>, <surface name>): <mesh attribute number>
# Out:
# {(1, 'cross'): 1,
#  (2, 'pad'): 2,
#  (3, 'launch_pad'): 3,
#  (4, 'launch_pad'): 4,
#  (1, 'josephson_junction'): 5,
#  (3, 'feedline_port1'): 6,
#  (4, 'feedline_port2'): 7,
#  (5, 'trace'): 8,
#  (7, 'trace'): 9,
#  (1, 'gap'): 11,
#  (2, 'padGap'): 12}

# %% [markdown]
# ## Mesh the design
#
# now that we have defined a dictionary for the Quantum Metal surfaces we want to give boundary conditions, we can actually mesh our design:
#
# > For time constraints of this demo, we use a coarse mesh and will not implement AMR. In practice, one should either start with a fine mesh (if you have strong previous knowledge of the field distributions) or apply AMR.

# %%
mesh_dir = "mesh/"
meshfile = "eigenmode_epr.msh"
path_to_mesh = mesh_dir + meshfile

## mesh the design --> returns pandas.dataframe of labeled mesh attributes ##
## look at readthedocs, mesh_Quantum_Metal_design has a lot of flexibility to control surface mesh size, volume mesh size, substrate size, etc ## 
attributes_table = mesh.mesh_Quantum_Metal_design(design,
                                                  output_mesh=path_to_mesh,
                                                  Attributes=attributes,
                                                  );
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 97 (Line)
# Info    : [ 10%] Meshing curve 98 (Line)
# Info    : [ 10%] Meshing curve 99 (Line)
# Info    : [ 10%] Meshing curve 100 (Line)
# Info    : [ 10%] Meshing curve 293 (Line)
# Info    : [ 10%] Meshing curve 467 (Line)
# Info    : [ 10%] Meshing curve 468 (Line)
# Info    : [ 10%] Meshing curve 469 (Line)
# Info    : [ 10%] Meshing curve 470 (Line)
# Info    : [ 10%] Meshing curve 471 (Line)
# Info    : [ 10%] Meshing curve 472 (Line)
# Info    : [ 10%] Meshing curve 473 (Line)
# Info    : [ 10%] Meshing curve 474 (Line)
# Info    : [ 10%] Meshing curve 475 (Line)
# Info    : [ 10%] Meshing curve 476 (Line)
# Info    : [ 10%] Meshing curve 477 (Line)
# Info    : [ 10%] Meshing curve 478 (Line)
# Info    : [ 10%] Meshing curve 479 (Line)
# Info    : [ 10%] Meshing curve 480 (Line)
# Info    : [ 10%] Meshing curve 481 (Line)
# Info    : [ 10%] Meshing curve 482 (Line)
# Info    : [ 10%] Meshing curve 483 (Line)
# Info    : [ 10%] Meshing curve 484 (Line)
# Info    : [ 10%] Meshing curve 485 (Line)
# Info    : [ 10%] Meshing curve 486 (Line)
# Info    : [ 10%] Meshing curve 487 (Line)
# Info    : [ 10%] Meshing curve 488 (Line)
# Info    : [ 10%] Meshing curve 489 (Line)
# Info    : [ 10%] Meshing curve 490 (Line)
# Info    : [ 10%] Meshing curve 491 (Line)
# Info    : [ 10%] Meshing curve 492 (Line)
# Info    : [ 10%] Meshing curve 493 (Line)
# Info    : [ 10%] Meshing curve 494 (Line)
# Info    : [ 10%] Meshing curve 495 (Line)
# Info    : [ 10%] Meshing curve 496 (Line)
# Info    : [ 10%] Meshing curve 497 (Line)
# Info    : [ 10%] Meshing curve 498 (Line)
# Info    : [ 10%] Meshing curve 499 (Line)
# Info    : [ 10%] Meshing curve 500 (Line)
# Info    : [ 10%] Meshing curve 501 (Line)
# Info    : [ 10%] Meshing curve 502 (Line)
# Info    : [ 10%] Meshing curve 503 (Line)
# Info    : [ 10%] Meshing curve 504 (Line)
# Info    : [ 10%] Meshing curve 505 (Line)
# Info    : [ 10%] Meshing curve 506 (Line)
# Info    : [ 10%] Meshing curve 507 (Line)
# Info    : [ 10%] Meshing curve 508 (Line)
# Info    : [ 10%] Meshing curve 509 (Line)
# Info    : [ 10%] Meshing curve 510 (Line)
# Info    : [ 10%] Meshing curve 511 (Line)
# Info    : [ 10%] Meshing curve 512 (Line)
# Info    : [ 10%] Meshing curve 513 (Line)
# Info    : [ 10%] Meshing curve 514 (Line)
# Info    : [ 10%] Meshing curve 515 (Line)
# Info    : [ 10%] Meshing curve 516 (Line)
# Info    : [ 10%] Meshing curve 517 (Line)
# Info    : [ 10%] Meshing curve 518 (Line)
# Info    : [ 10%] Meshing curve 519 (Line)
# Info    : [ 10%] Meshing curve 520 (Line)
# Info    : [ 10%] Meshing curve 521 (Line)
# Info    : [ 10%] Meshing curve 522 (Line)
# Info    : [ 10%] Meshing curve 523 (Line)
# Info    : [ 10%] Meshing curve 524 (Line)
# Info    : [ 10%] Meshing curve 525 (Line)
# Info    : [ 10%] Meshing curve 526 (Line)
# Info    : [ 10%] Meshing curve 527 (Line)
# Info    : [ 10%] Meshing curve 528 (Line)
# Info    : [ 10%] Meshing curve 529 (Line)
# Info    : [ 10%] Meshing curve 530 (Line)
# Info    : [ 10%] Meshing curve 531 (Line)
# Info    : [ 10%] Meshing curve 532 (Line)
# Info    : [ 10%] Meshing curve 533 (Line)
# Info    : [ 10%] Meshing curve 534 (Line)
# Info    : [ 10%] Meshing curve 535 (Line)
# Info    : [ 10%] Meshing curve 536 (Line)
# Info    : [ 10%] Meshing curve 537 (Line)
# Info    : [ 10%] Meshing curve 538 (Line)
# Info    : [ 10%] Meshing curve 539 (Line)
# Info    : [ 10%] Meshing curve 540 (Line)
# Info    : [ 10%] Meshing curve 541 (Line)
# Info    : [ 10%] Meshing curve 542 (Line)
# Info    : [ 10%] Meshing curve 543 (Line)
# Info    : [ 10%] Meshing curve 544 (Line)
# Info    : [ 10%] Meshing curve 545 (Line)
# Info    : [ 20%] Meshing curve 546 (Line)
# Info    : [ 20%] Meshing curve 547 (Line)
# Info    : [ 20%] Meshing curve 548 (Line)
# Info    : [ 20%] Meshing curve 549 (Line)
# Info    : [ 20%] Meshing curve 550 (Line)
# Info    : [ 20%] Meshing curve 551 (Line)
# Info    : [ 20%] Meshing curve 552 (Line)
# Info    : [ 20%] Meshing curve 553 (Line)
# Info    : [ 20%] Meshing curve 554 (Line)
# Info    : [ 20%] Meshing curve 555 (Line)
# Info    : [ 20%] Meshing curve 556 (Line)
# Info    : [ 20%] Meshing curve 557 (Line)
# Info    : [ 20%] Meshing curve 558 (Line)
# Info    : [ 20%] Meshing curve 559 (Line)
# Info    : [ 20%] Meshing curve 560 (Line)
# Info    : [ 20%] Meshing curve 561 (Line)
# Info    : [ 20%] Meshing curve 562 (Line)
# Info    : [ 20%] Meshing curve 563 (Line)
# Info    : [ 20%] Meshing curve 564 (Line)
# Info    : [ 20%] Meshing curve 565 (Line)
# Info    : [ 20%] Meshing curve 566 (Line)
# Info    : [ 20%] Meshing curve 567 (Line)
# Info    : [ 20%] Meshing curve 568 (Line)
# Info    : [ 20%] Meshing curve 569 (Line)
# Info    : [ 20%] Meshing curve 570 (Line)
# Info    : [ 20%] Meshing curve 571 (Line)
# Info    : [ 20%] Meshing curve 572 (Line)
# Info    : [ 20%] Meshing curve 573 (Line)
# Info    : [ 20%] Meshing curve 574 (Line)
# Info    : [ 20%] Meshing curve 575 (Line)
# Info    : [ 20%] Meshing curve 576 (Line)
# Info    : [ 20%] Meshing curve 577 (Line)
# Info    : [ 20%] Meshing curve 578 (Line)
# Info    : [ 20%] Meshing curve 579 (Line)
# Info    : [ 20%] Meshing curve 580 (Line)
# Info    : [ 20%] Meshing curve 581 (Line)
# Info    : [ 20%] Meshing curve 582 (Line)
# Info    : [ 20%] Meshing curve 583 (Line)
# Info    : [ 20%] Meshing curve 584 (Line)
# Info    : [ 20%] Meshing curve 585 (Line)
# Info    : [ 20%] Meshing curve 586 (Line)
# Info    : [ 20%] Meshing curve 587 (Line)
# Info    : [ 20%] Meshing curve 588 (Line)
# Info    : [ 20%] Meshing curve 589 (Line)
# Info    : [ 20%] Meshing curve 590 (Line)
# Info    : [ 20%] Meshing curve 591 (Line)
# Info    : [ 20%] Meshing curve 592 (Line)
# Info    : [ 20%] Meshing curve 593 (Line)
# Info    : [ 20%] Meshing curve 594 (Line)
# Info    : [ 20%] Meshing curve 595 (Line)
# Info    : [ 20%] Meshing curve 596 (Line)
# Info    : [ 20%] Meshing curve 597 (Line)
# Info    : [ 20%] Meshing curve 598 (Line)
# Info    : [ 20%] Meshing curve 599 (Line)
# Info    : [ 20%] Meshing curve 600 (Line)
# Info    : [ 20%] Meshing curve 601 (Line)
# Info    : [ 20%] Meshing curve 602 (Line)
# Info    : [ 20%] Meshing curve 603 (Line)
# Info    : [ 20%] Meshing curve 604 (Line)
# Info    : [ 20%] Meshing curve 605 (Line)
# Info    : [ 20%] Meshing curve 606 (Line)
# Info    : [ 20%] Meshing curve 607 (Line)
# Info    : [ 20%] Meshing curve 608 (Line)
# Info    : [ 20%] Meshing curve 609 (Line)
# Info    : [ 20%] Meshing curve 610 (Line)
# Info    : [ 20%] Meshing curve 611 (Line)
# Info    : [ 20%] Meshing curve 612 (Line)
# Info    : [ 20%] Meshing curve 613 (Line)
# Info    : [ 20%] Meshing curve 614 (Line)
# Info    : [ 30%] Meshing curve 676 (Line)
# Info    : [ 30%] Meshing curve 677 (Line)
# Info    : [ 30%] Meshing curve 678 (Line)
# Info    : [ 30%] Meshing curve 679 (Line)
# Info    : [ 30%] Meshing curve 680 (Line)
# Info    : [ 30%] Meshing curve 681 (Line)
# Info    : [ 30%] Meshing curve 682 (Line)
# Info    : [ 30%] Meshing curve 683 (Line)
# Info    : [ 30%] Meshing curve 684 (Line)
# Info    : [ 30%] Meshing curve 685 (Line)
# Info    : [ 30%] Meshing curve 686 (Line)
# Info    : [ 30%] Meshing curve 687 (Line)
# Info    : [ 30%] Meshing curve 688 (Line)
# Info    : [ 30%] Meshing curve 689 (Line)
# Info    : [ 30%] Meshing curve 690 (Line)
# Info    : [ 30%] Meshing curve 691 (Line)
# Info    : [ 30%] Meshing curve 692 (Line)
# Info    : [ 30%] Meshing curve 693 (Line)
# Info    : [ 30%] Meshing curve 694 (Line)
# Info    : [ 30%] Meshing curve 695 (Line)
# Info    : [ 30%] Meshing curve 696 (Line)
# Info    : [ 30%] Meshing curve 697 (Line)
# Info    : [ 30%] Meshing curve 698 (Line)
# Info    : [ 30%] Meshing curve 699 (Line)
# Info    : [ 30%] Meshing curve 700 (Line)
# Info    : [ 30%] Meshing curve 701 (Line)
# Info    : [ 30%] Meshing curve 702 (Line)
# Info    : [ 30%] Meshing curve 703 (Line)
# Info    : [ 30%] Meshing curve 704 (Line)
# Info    : [ 30%] Meshing curve 705 (Line)
# Info    : [ 30%] Meshing curve 706 (Line)
# Info    : [ 30%] Meshing curve 707 (Line)
# Info    : [ 30%] Meshing curve 708 (Line)
# Info    : [ 30%] Meshing curve 709 (Line)
# Info    : [ 30%] Meshing curve 710 (Line)
# Info    : [ 30%] Meshing curve 711 (Line)
# Info    : [ 30%] Meshing curve 712 (Line)
# Info    : [ 30%] Meshing curve 713 (Line)
# Info    : [ 40%] Meshing curve 714 (Line)
# Info    : [ 40%] Meshing curve 715 (Line)
# Info    : [ 40%] Meshing curve 716 (Line)
# Info    : [ 40%] Meshing curve 717 (Line)
# Info    : [ 40%] Meshing curve 718 (Line)
# Info    : [ 40%] Meshing curve 719 (Line)
# Info    : [ 40%] Meshing curve 720 (Line)
# Info    : [ 40%] Meshing curve 721 (Line)
# Info    : [ 40%] Meshing curve 722 (Line)
# Info    : [ 40%] Meshing curve 723 (Line)
# Info    : [ 40%] Meshing curve 724 (Line)
# Info    : [ 40%] Meshing curve 725 (Line)
# Info    : [ 40%] Meshing curve 726 (Line)
# Info    : [ 40%] Meshing curve 727 (Line)
# Info    : [ 40%] Meshing curve 728 (Line)
# Info    : [ 40%] Meshing curve 729 (Line)
# Info    : [ 40%] Meshing curve 730 (Line)
# Info    : [ 40%] Meshing curve 731 (Line)
# Info    : [ 40%] Meshing curve 732 (Line)
# Info    : [ 40%] Meshing curve 733 (Line)
# Info    : [ 40%] Meshing curve 734 (Line)
# Info    : [ 40%] Meshing curve 735 (Line)
# Info    : [ 40%] Meshing curve 736 (Line)
# Info    : [ 40%] Meshing curve 737 (Line)
# Info    : [ 40%] Meshing curve 738 (Line)
# Info    : [ 40%] Meshing curve 739 (Line)
# Info    : [ 40%] Meshing curve 740 (Line)
# Info    : [ 40%] Meshing curve 741 (Line)
# Info    : [ 40%] Meshing curve 742 (Line)
# Info    : [ 40%] Meshing curve 743 (Line)
# Info    : [ 40%] Meshing curve 744 (Line)
# Info    : [ 40%] Meshing curve 745 (Line)
# Info    : [ 40%] Meshing curve 746 (Line)
# Info    : [ 40%] Meshing curve 747 (Line)
# Info    : [ 40%] Meshing curve 748 (Line)
# Info    : [ 40%] Meshing curve 749 (Line)
# Info    : [ 40%] Meshing curve 750 (Line)
# Info    : [ 40%] Meshing curve 751 (Line)
# Info    : [ 40%] Meshing curve 752 (Line)
# Info    : [ 40%] Meshing curve 753 (Line)
# Info    : [ 40%] Meshing curve 754 (Line)
# Info    : [ 40%] Meshing curve 755 (Line)
# Info    : [ 40%] Meshing curve 756 (Line)
# Info    : [ 40%] Meshing curve 757 (Line)
# Info    : [ 40%] Meshing curve 758 (Line)
# Info    : [ 40%] Meshing curve 759 (Line)
# Info    : [ 40%] Meshing curve 760 (Line)
# Info    : [ 40%] Meshing curve 761 (Line)
# Info    : [ 40%] Meshing curve 762 (Line)
# Info    : [ 40%] Meshing curve 763 (Line)
# Info    : [ 40%] Meshing curve 764 (Line)
# Info    : [ 40%] Meshing curve 765 (Line)
# Info    : [ 40%] Meshing curve 766 (Line)
# Info    : [ 40%] Meshing curve 767 (Line)
# Info    : [ 40%] Meshing curve 768 (Line)
# Info    : [ 40%] Meshing curve 769 (Line)
# Info    : [ 40%] Meshing curve 770 (Line)
# Info    : [ 40%] Meshing curve 771 (Line)
# Info    : [ 40%] Meshing curve 772 (Line)
# Info    : [ 40%] Meshing curve 773 (Line)
# Info    : [ 40%] Meshing curve 774 (Line)
# Info    : [ 40%] Meshing curve 775 (Line)
# Info    : [ 40%] Meshing curve 776 (Line)
# Info    : [ 40%] Meshing curve 777 (Line)
# Info    : [ 40%] Meshing curve 778 (Line)
# Info    : [ 40%] Meshing curve 779 (Line)
# Info    : [ 40%] Meshing curve 780 (Line)
# Info    : [ 40%] Meshing curve 781 (Line)
# Info    : [ 40%] Meshing curve 782 (Line)
# Info    : [ 40%] Meshing curve 783 (Line)
# Info    : [ 40%] Meshing curve 784 (Line)
# Info    : [ 40%] Meshing curve 785 (Line)
# Info    : [ 40%] Meshing curve 786 (Line)
# Info    : [ 40%] Meshing curve 787 (Line)
# Info    : [ 40%] Meshing curve 788 (Line)
# Info    : [ 40%] Meshing curve 789 (Line)
# Info    : [ 40%] Meshing curve 790 (Line)
# Info    : [ 40%] Meshing curve 791 (Line)
# Info    : [ 40%] Meshing curve 792 (Line)
# Info    : [ 40%] Meshing curve 793 (Line)
# Info    : [ 40%] Meshing curve 794 (Line)
# Info    : [ 40%] Meshing curve 795 (Line)
# Info    : [ 40%] Meshing curve 796 (Line)
# Info    : [ 40%] Meshing curve 797 (Line)
# Info    : [ 90%] Meshing curve 1158 (Line)
# Info    : [ 90%] Meshing curve 1159 (Line)
# Info    : [ 90%] Meshing curve 1160 (Line)
# Info    : [ 90%] Meshing curve 1161 (Line)
# Info    : [ 90%] Meshing curve 1162 (Line)
# Info    : [ 90%] Meshing curve 1163 (Line)
# Info    : [ 90%] Meshing curve 1164 (Line)
# Info    : [ 90%] Meshing curve 1165 (Line)
# Info    : [ 90%] Meshing curve 1166 (Line)
# Info    : [ 90%] Meshing curve 1167 (Line)
# Info    : [ 90%] Meshing curve 1168 (Line)
# Info    : [ 90%] Meshing curve 1169 (Line)
# Info    : [ 90%] Meshing curve 1170 (Line)
# Info    : [ 90%] Meshing curve 1171 (Line)
# Info    : [ 90%] Meshing curve 1172 (Line)
# Info    : [ 90%] Meshing curve 1173 (Line)
# Info    : [ 90%] Meshing curve 1174 (Line)
# Info    : [ 90%] Meshing curve 1175 (Line)
# Info    : [ 90%] Meshing curve 1176 (Line)
# Info    : [ 90%] Meshing curve 1177 (Line)
# Info    : [ 90%] Meshing curve 1178 (Line)
# Info    : [ 90%] Meshing curve 1179 (Line)
# Info    : [ 90%] Meshing curve 1180 (Line)
# Info    : [ 90%] Meshing curve 1181 (Line)
# Info    : [ 90%] Meshing curve 1182 (Line)
# Info    : [ 90%] Meshing curve 1183 (Line)
# Info    : [ 90%] Meshing curve 1184 (Line)
# Info    : [ 90%] Meshing curve 1185 (Line)
# Info    : [ 90%] Meshing curve 1186 (Line)
# Info    : [ 90%] Meshing curve 1187 (Line)
# Info    : [ 90%] Meshing curve 1188 (Line)
# Info    : [ 90%] Meshing curve 1189 (Line)
# Info    : [ 90%] Meshing curve 1190 (Line)
# Info    : [ 90%] Meshing curve 1191 (Line)
# Info    : [ 90%] Meshing curve 1192 (Line)
# Info    : [ 90%] Meshing curve 1193 (Line)
# Info    : [ 90%] Meshing curve 1194 (Line)
# Info    : [ 90%] Meshing curve 1195 (Line)
# Info    : [ 90%] Meshing curve 1196 (Line)
# Info    : [ 90%] Meshing curve 1197 (Line)
# Info    : [ 90%] Meshing curve 1198 (Line)
# Info    : [ 90%] Meshing curve 1199 (Line)
# Info    : [ 90%] Meshing curve 1200 (Line)
# Info    : [ 90%] Meshing curve 1201 (Line)
# Info    : [ 90%] Meshing curve 1202 (Line)
# Info    : [ 90%] Meshing curve 1203 (Line)
# Info    : [ 90%] Meshing curve 1204 (Line)
# Info    : [ 90%] Meshing curve 1205 (Line)
# Info    : [ 90%] Meshing curve 1206 (Line)
# Info    : [ 90%] Meshing curve 1207 (Line)
# Info    : [ 90%] Meshing curve 1208 (Line)
# Info    : [ 90%] Meshing curve 1209 (Line)
# Info    : [ 90%] Meshing curve 1210 (Line)
# Info    : [ 90%] Meshing curve 1211 (Line)
# Info    : [ 90%] Meshing curve 1212 (Line)
# Info    : [ 90%] Meshing curve 1213 (Line)
# Info    : [ 90%] Meshing curve 1214 (Line)
# Info    : [ 90%] Meshing curve 1215 (Line)
# Info    : [ 90%] Meshing curve 1216 (Line)
# Info    : [100%] Meshing curve 1280 (Line)
# Info    : [100%] Meshing curve 1281 (Line)
# Info    : [100%] Meshing curve 1282 (Line)
# Info    : [100%] Meshing curve 1283 (Line)
# Info    : [100%] Meshing curve 1284 (Line)
# Info    : [100%] Meshing curve 1285 (Line)
# Info    : [100%] Meshing curve 1286 (Line)
# Info    : [100%] Meshing curve 1287 (Line)
# Info    : [100%] Meshing curve 1288 (Line)
# Info    : [100%] Meshing curve 1289 (Line)
# Info    : [100%] Meshing curve 1290 (Line)
# Info    : [100%] Meshing curve 1291 (Line)
# Info    : [100%] Meshing curve 1292 (Line)
# Info    : [100%] Meshing curve 1293 (Line)
# Info    : [100%] Meshing curve 1294 (Line)
# Info    : [100%] Meshing curve 1295 (Line)
# Info    : [100%] Meshing curve 1296 (Line)
# Info    : [100%] Meshing curve 1297 (Line)
# Info    : [100%] Meshing curve 1298 (Line)
# Info    : [100%] Meshing curve 1299 (Line)
# Info    : Done meshing 1D (Wall 5.57519s, CPU 5.52197s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 15 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 17 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 19 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 21 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 22 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 23 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 24 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 25 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 26 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 27 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 28 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 29 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 30 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 31 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 32 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 33 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 34 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 35 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 36 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 37 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 38 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 39 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 40 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 41 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 42 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 43 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 44 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 45 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 46 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 47 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 48 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 49 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 50 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 51 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 52 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 53 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 54 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 55 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 56 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 57 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 58 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.733622s, CPU 0.725319s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 2 volumes with 1 connected component
# Info    : Tetrahedrizing 27107 nodes...
# Info    : Done tetrahedrizing 27115 nodes (Wall 0.993864s, CPU 0.984702s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 1.34744s, CPU 1.3221s)
# Info    : Found volume 1
# Info    : Found volume 2
# Info    : It. 0 - 0 nodes created - worst tet radius 9.27627 (nodes removed 0 0)
# Info    : It. 500 - 500 nodes created - worst tet radius 2.59924 (nodes removed 0 0)
# Info    : It. 1000 - 1000 nodes created - worst tet radius 1.93997 (nodes removed 0 0)
# Info    : It. 1500 - 1500 nodes created - worst tet radius 1.69828 (nodes removed 0 0)
# Info    : It. 2000 - 1998 nodes created - worst tet radius 1.56736 (nodes removed 0 2)
# Info    : It. 2500 - 2498 nodes created - worst tet radius 1.43446 (nodes removed 0 2)
# Info    : It. 3000 - 2998 nodes created - worst tet radius 1.36194 (nodes removed 0 2)
# Info    : It. 3500 - 3498 nodes created - worst tet radius 1.30616 (nodes removed 0 2)
# Info    : It. 4000 - 3998 nodes created - worst tet radius 1.26779 (nodes removed 0 2)
# Info    : It. 4500 - 4498 nodes created - worst tet radius 1.2256 (nodes removed 0 2)
# Info    : It. 5000 - 4998 nodes created - worst tet radius 1.19733 (nodes removed 0 2)
# Info    : It. 5500 - 5498 nodes created - worst tet radius 1.17371 (nodes removed 0 2)
# Info    : It. 6000 - 5998 nodes created - worst tet radius 1.15256 (nodes removed 0 2)
# Info    : It. 6500 - 6498 nodes created - worst tet radius 1.13314 (nodes removed 0 2)
# Info    : It. 7000 - 6998 nodes created - worst tet radius 1.11345 (nodes removed 0 2)
# Info    : It. 7500 - 7498 nodes created - worst tet radius 1.09578 (nodes removed 0 2)
# Info    : It. 8000 - 7998 nodes created - worst tet radius 1.07941 (nodes removed 0 2)
# Info    : It. 8500 - 8498 nodes created - worst tet radius 1.06152 (nodes removed 0 2)
# Info    : It. 9000 - 8998 nodes created - worst tet radius 1.04442 (nodes removed 0 2)
# Info    : It. 9500 - 9498 nodes created - worst tet radius 1.02914 (nodes removed 0 2)
# Info    : It. 10000 - 9996 nodes created - worst tet radius 1.01576 (nodes removed 0 4)
# Info    : It. 10500 - 10494 nodes created - worst tet radius 1.00182 (nodes removed 0 6)
# Info    : 3D refinement terminated (37648 nodes total):
# Info    :  - 506 Delaunay cavities modified for star shapeness
# Info    :  - 6 nodes could not be inserted
# Info    :  - 194533 tetrahedra created in 1.77145 sec. (109815 tets/s)
# Info    : 525 node relocations
# Info    : Done meshing 3D (Wall 4.00596s, CPU 3.92309s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 5.77933e+09) with worst = 0.00284761 / average = 0.514949:
# Info    : 0.00 < quality < 0.10 :       570 elements
# Info    : 0.10 < quality < 0.20 :      4669 elements
# Info    : 0.20 < quality < 0.30 :     14268 elements
# Info    : 0.30 < quality < 0.40 :     19231 elements
# Info    : 0.40 < quality < 0.50 :     15487 elements
# Info    : 0.50 < quality < 0.60 :      9036 elements
# Info    : 0.60 < quality < 0.70 :      6830 elements
# Info    : 0.70 < quality < 0.80 :      9614 elements
# Info    : 0.80 < quality < 0.90 :     11931 elements
# Info    : 0.90 < quality < 1.00 :      5584 elements
# Info    : 3838 edge swaps, 705 node relocations (volume = 5.77933e+09): worst = 0.0117473 / average = 0.528917 (Wall 0.617075s, CPU 0.603025s)
# Info    : 4516 edge swaps, 1092 node relocations (volume = 5.77933e+09): worst = 0.0117473 / average = 0.530059 (Wall 1.17796s, CPU 1.15036s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :        16 elements
# Info    : 0.10 < quality < 0.20 :      2790 elements
# Info    : 0.20 < quality < 0.30 :     11917 elements
# Info    : 0.30 < quality < 0.40 :     19064 elements
# Info    : 0.40 < quality < 0.50 :     15370 elements
# Info    : 0.50 < quality < 0.60 :      9523 elements
# Info    : 0.60 < quality < 0.70 :      7100 elements
# Info    : 0.70 < quality < 0.80 :      9667 elements
# Info    : 0.80 < quality < 0.90 :     11913 elements
# Info    : 0.90 < quality < 1.00 :      5560 elements
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 5.77933e+09) with worst = 0.00284761 / average = 0.515016:
# Info    : 0.00 < quality < 0.10 :       565 elements
# Info    : 0.10 < quality < 0.20 :      4678 elements
# Info    : 0.20 < quality < 0.30 :     14250 elements
# Info    : 0.30 < quality < 0.40 :     19240 elements
# Info    : 0.40 < quality < 0.50 :     15524 elements
# Info    : 0.50 < quality < 0.60 :      9101 elements
# Info    : 0.60 < quality < 0.70 :      6843 elements
# Info    : 0.70 < quality < 0.80 :      9507 elements
# Info    : 0.80 < quality < 0.90 :     11967 elements
# Info    : 0.90 < quality < 1.00 :      5638 elements
# Info    : 3818 edge swaps, 705 node relocations (volume = 5.77933e+09): worst = 0.0117473 / average = 0.528948 (Wall 0.54071s, CPU 0.534118s)
# Info    : 4486 edge swaps, 1061 node relocations (volume = 5.77933e+09): worst = 0.0117473 / average = 0.529862 (Wall 1.03778s, CPU 1.02883s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :        17 elements
# Info    : 0.10 < quality < 0.20 :      2785 elements
# Info    : 0.20 < quality < 0.30 :     11926 elements
# Info    : 0.30 < quality < 0.40 :     19105 elements
# Info    : 0.40 < quality < 0.50 :     15427 elements
# Info    : 0.50 < quality < 0.60 :      9538 elements
# Info    : 0.60 < quality < 0.70 :      7125 elements
# Info    : 0.70 < quality < 0.80 :      9593 elements
# Info    : 0.80 < quality < 0.90 :     11972 elements
# Info    : 0.90 < quality < 1.00 :      5589 elements
# Info    : Done optimizing mesh (Wall 2.36228s, CPU 2.31735s)
# Info    : 37648 nodes 253216 elements
# Info    : Writing 'mesh/eigenmode_epr.msh'...
# Info    : Done writing 'mesh/eigenmode_epr.msh'

# %% [markdown]
# `pypalace.mesh.mesh_Quantum_Metal_design` returns an ordered dataframe of the mesh components. We will use these to build our Palace configuration file. Notice this function automatically makes a ground plane, an air box, a substrate box, and the far field.

# %%
attributes_table
# Out:
#                      Name  ID     Type
# 0                1__cross   1  Surface
# 9                  1__gap  11  Surface
# 10              2__padGap  12  Surface
# 13              substrate  13   Volume
# 14                    air  14   Volume
# 11           ground_plane  15  Surface
# 12              far_field  16  Surface
# 1                  2__pad   2  Surface
# 2           3__launch_pad   3  Surface
# 3           4__launch_pad   4  Surface
# 4   1__josephson_junction   5  Surface
# 5       3__feedline_port1   6  Surface
# 6       4__feedline_port2   7  Surface
# 7                5__trace   8  Surface
# 8                7__trace   9  Surface

# %% [markdown]
# # Build Palace configuration file with pyPalace
#
# pyPalace follows the Palace configuration schema one-to-one. In this sense, the pyPalace configuration building using `pypalace.Config` and `pypalace.builder` follows directly from the [Palace config documentation](https://awslabs.github.io/palace/stable/config/config/).

# %%
from pypalace import Config
from pypalace.builder import Model, Domains, Boundaries, Solver  # these match one-to-one with Palace config syntax

# %%
''' choose path & name for Palace configuration file we will build below '''
config_dir = "config/"
path_to_config = config_dir + "eigenmode_epr.json"

# %% [markdown]
# ## Initialize pyPalace Config object:

# %%
eigenmode_config = Config(path_to_config)

# %% [markdown]
# ## Add `config["Problems"]` and `config["Model"]`

# %%
eigenmode_config.add_Problem(Type="Eigenmode",
                             Output="eigenmode_output")

# don't use here but this is how we could add adaptive mesh refinement
#AMR = Model.Refinement(Tol = 1e-6,MaxIts = 3)

# define config["Model"] block
eigenmode_config.add_Model(Mesh = path_to_mesh, # point to our meshfile
                    L0 = 1e-6,# mesh units relative to meters
                    #Refinement=AMR
                    )

# %% [markdown]
# ## Add `config["Domains"]`
#
# Used to define properties and postprocessing for meshed volumes.
#
# ### <u>The importance of bulk material properties</u>
#
# Superconducting circuits are fabricated on a dielectric substrate (usually silicon or sapphire). To accurately capture the behavior of our devices, we must model the substrate appropriately — assign accurate values for the electric permittivity ($\epsilon$) and bulk loss tangent ($\tan\delta$). The scaling relations below follow standard circuit-QED considerations ([Blais et al., *Rev. Mod. Phys.* **93**, 025005 (2021)](https://doi.org/10.1103/RevModPhys.93.025005)).
#
# <u>substrate permittivity</u>
#
# Increasing the substrate permittivity increases the capacitance of both CPW resonators and transmon qubits. In general,
#
# $$
# C \propto \epsilon.
# $$
#
# For a CPW resonator:
#
# $$
# v_p = \frac{1}{\sqrt{LC}} \rightarrow f_r \propto v_p \propto \frac{1}{\sqrt{\epsilon_{\mathrm{eff}}}}
# $$
#
# For a transmon qubit:
#
# $$E_C = \frac{e^2}{2C_\Sigma} \rightarrow f_q \approx \frac{\sqrt{8E_J E_C} - E_C}{h} \propto \frac{1}{\sqrt{\epsilon}}$$
#
# To leading order $f_q$ is set by the $\sqrt{8E_J E_C}$ term, giving $f_q \propto 1/\sqrt{\epsilon}$; the $-E_C/h$ anharmonicity term scales as $1/\epsilon$.
#
# Thus, increasing the substrate permittivity generally lowers both resonator and qubit eigenfrequencies. However, kinetic inductance (an extra inductance, on top of the usual magnetic inductance, that arises in superconducting devices) can also lower the frequency. Since higher inductance means a lower frequency ($f \approx 1/2\pi\sqrt{LC}$), it acts much as permittivity does through the capacitance. As a result, $\epsilon$ cannot be uniquely determined by matching to a measured frequency alone ([Elkin et al., arXiv:2511.20774 (2025)](https://arxiv.org/abs/2511.20774), Sec. VI A).
#
# <u>bulk loss tangent</u>
#
# The bulk loss tangent ($\tan\delta$) quantifies dielectric dissipation in a material. Unlike the permittivity, it has little effect on the mode frequency and instead affects the mode lifetime.
#
# For a resonator:
#
# $$
# Q_{\mathrm{dielectric}} \approx \frac{1}{p\,\tan\delta}
# \rightarrow
# \kappa = \frac{\omega_r}{Q} \propto \tan\delta
# $$
#
# where $p$ is the dielectric participation ratio.
#
# Thus, increasing the bulk loss tangent increases dielectric loss, lowers the quality factor, and broadens the resonator linewidth.
#
# It is also important to account for material anisotropy when applicable, particularly for sapphire substrates whose dielectric properties vary with crystallographic direction.
#
# <u>Common substrate parameters for superconducting circuits</u>
#
# | Substrate | Relative Permittivity ($\epsilon$) | Bulk Loss Tangent ($\tan\delta$) |
# | :---: | :---: | :---: |
# | Cryogenic Silicon | 11.45 | $10^{-7} - 10^{-6}$ |
# | Sapphire\* | $\epsilon_\perp \approx 9.27$, $\epsilon_\parallel \approx 11.35$ | $10^{-9} - 10^{-8}$ |
#
# \* Sapphire is anisotropic. Representative cryogenic silicon values are from [Checchin et al., *Phys. Rev. Applied* **18**, 034013 (2022)](https://doi.org/10.1103/PhysRevApplied.18.034013); sapphire values are from [Read et al., *Phys. Rev. Applied* **19**, 034064 (2023)](https://doi.org/10.1103/PhysRevApplied.19.034064).
#
# **Note:** Material properties can vary between substrates and fabrication processes. Consequently, it is important to use material parameters that accurately reflect the specific substrate being fabricated whenever possible.

# %%
# from the attribute table above:
substrate_id = 13
airbox_id = 14

# define materials
silicon = Domains.Material(Attributes = [substrate_id], # attributes to give the properties below to:
                                     Permeability=1.0, # magnetic permeability
                                     Permittivity=11.45, # electric permittivity
                                     LossTan=1e-07) # bulk loss tangent

airbox = Domains.Material([airbox_id],1.0,1.0,0.0)

# will not use this here but an example of adding domain postprocessing:


materials = [silicon,airbox] # material list for input into add_Domains()
eigenmode_config.add_Domains(Materials = materials) # add materials to our configuration file

# %% [markdown]
# ## Add `config["Boundaries"]`
#
# Used to define boundary conditions and postprocessing for meshed surfaces.
#
# ### Some notes on boundary conditions for eigenmode simulations of superconducting circuits
# ### <u>Why do we assign PECs to our superconducting metals?</u>
#
# Superconductivity is defined by two major phenomenological properties: zero DC resistance and the Meissner effect (expulsion of magnetic fields). The former is the property that allows superconductors to be well approximated as perfect electric conductors (PECs) in electromagnetic simulations.
#
# Some notes on approximating the superconducting thin-films as PECs:
#
# 1.  PECs capture the effectively lossless electrical response of superconductors. The more general treatment replaces the PEC with a surface impedance boundary condition, which additionally accounts for kinetic inductance and superconducting loss ([Elkin et al., arXiv:2511.20774 (2025)](https://arxiv.org/abs/2511.20774), Eq. (9) and Sec. VI A). PEC is the lossless, zero-kinetic-inductance limit of that condition.
# 2. The London penetration depth ($\lambda_L \sim 50$ nm for Al) is small compared to the lateral circuit dimensions of hundreds of microns, but it is often comparable to the film thickness. The current and field therefore penetrate through the film rather than being excluded from it (arXiv:2511.20774, Sec. VI A). PEC is an approximation that treats the metal as lossless and neglects the kinetic inductance (see items 1 and 3), rather than a statement that the field is confined to the air and substrate.
# 3. Kinetic inductance shifts the mode frequencies and is set by $\lambda_L$, which for thin films can be comparable to the film thickness. The PEC approximation neglects this shift. It is often a small correction for the geometries here, but that should be checked against measurement rather than assumed ([Elkin et al., arXiv:2511.20774 (2025)](https://arxiv.org/abs/2511.20774), Sec. VI A).
# 4. Superconductivity is a bulk property, whereas our metal components are represented as 2D surfaces in the simulation. A PEC boundary condition provides a natural way to model these thin superconducting films.
#
# The ground plane is also superconducting, so we assign it a PEC boundary condition as well.
#
# ### <u>Why do we need feedline ports in eigenmode simulations?</u>
#
# While it may be intuitive why we need feedline ports for driven simulations, their role in eigenmode simulations is more subtle. Eigenmode simulations can determine the resonant frequencies and field distributions of an isolated structure, but feedline ports are required to represent the external electromagnetic channels through which energy can escape. This enables Palace to quantify the resonator's coupling to the feedline and extract its external quality factor $Q_\text{ext}$, or equivalently the external decay rate $\kappa_\text{ext}$.
#
# ### <u>What is the far field?</u>
#
# The far field is the outer boundary of the simulation domain that represents the environment surrounding the device. For a superconducting quantum device, this would be the "packaging". For eigenmode simulations, assigning the far field to be a PEC BC is realistic since device packaging is made of metal. However, for radiative loss into open space, using an Absorbing BC can be useful.
#
# ### <u>Summary of eigenmode boundary conditions</u>
# | Surface | Boundary Condition |
# | :---: | :---: |
# | Circuit Components | PEC |
# | Ground Plane | PEC |
# | Far Field | PEC or Absorbing |
# | External ports | LumpedPort with $R=50 \:\: \Omega$ |
# | Josephson junctions | LumpedPort with $L = L_J \:\: [H]$
#
# We can also provide the $C_J$ to the junction LumpedPort to capture its capacitance but on average it can be safely neglected ($C_\Sigma = C_s + C_J \approx C_s$).
#
# ### <u>Boundary postprocessing: Interface dielectric loss</u>
# Interface dielectric loss arises from thin dielectric layers that form at material interfaces, such as metal–substrate (MS), metal–air (MA), and substrate–air (SA) boundaries. In superconducting circuits, these layers commonly originate from native metal oxides, surface contamination, adsorbed molecules, and interfacial material disorder introduced during fabrication. Although these layers are only a few nanometers thick, they can store a significant fraction of the electric field energy. Consequently, interface dielectric loss is often a dominant source of energy relaxation and decoherence in superconducting qubits and resonators, making it an important quantity to characterize during device design. One can estimate this loss by computing closed-form participation-ratio formulas for the MA/MS/SA decomposition across common qubit geometries, which can also serve as an independent check on numerical modeling, especially since these nm-thin interfaces are very hard to mesh. Such formulas are given by J. M. Martinis, npj Quantum Information 8, 26 (2022).
#
#
# Palace enables us to estimate interface dielectric loss through boundary postprocessing (`boundaries["Postprocessing"]["Dielectric"]`). In superconducting circuits, the contribution of a lossy interface is determined by both its participation ratio $p_i$ and loss tangent $\tan\delta_i$. In particular, $T_1$ decay can be characterized as ([Wang et al., *Appl. Phys. Lett.* **107**, 162601 (2015)](https://doi.org/10.1063/1.4934486)):
#
# $$
# \gamma =\omega_q\sum_i p_i \tan\delta_i + \Gamma_0
# $$
#
# where $i$ denotes MA, SA, and MS interfaces & $\Gamma_0$ accounts for other decay channels such as Purcell decay.
#
# <u>Surface dielectric properties</u>
#
# To estimate interface dielectric losses, we must assign each interface a surface dielectric permittivity ($\epsilon_i$), loss tangent ($\tan\delta_i$), and thickness ($t_i$). As with bulk material properties, accurate values are important for obtaining meaningful results from modeling. *However*, interface properties are extremely device- and process-dependent, as they can vary significantly with fabrication methods, surface treatments, contamination, and material quality.
#
# As an example, the representative values below are those used in that Martinis participation-ratio analysis and accompanying open-source calculator. The two metal-bounded interfaces (MA, MS) are modeled as aluminum oxide ($\epsilon \approx 9.8$) and the substrate–air interface as silicon dioxide ($\epsilon \approx 3.8$), reflecting the different native oxides that form at each boundary. The loss tangent here is a single representative value ($\sim 0.005$, typical for amorphous oxides) applied to all three:
#
# | Interface | Relative Permittivity ($\epsilon_i$) | Loss Tangent ($\tan\delta_i$) | Thickness ($t_i$) |
# | :---: | :---: | :---: | :---: |
# | Metal–Air (MA) | 9.8 | 0.005 | 2 nm |
# | Metal–Substrate (MS) | 9.8 | 0.005 | 2 nm |
# | Substrate–Air (SA) | 3.8 | 0.005 | 2 nm |
#
# The loss tangents are shown as a single representative value applied identically to all three interfaces. In practice, these loss tangents differ between interfaces and, because they vary so strongly with fabrication, are an important quantity to refine with measured, process-specific values. These values are difficult to obtain: a single interface's loss tangent cannot be measured directly, and is instead extracted by fitting the total measured loss across a series of resonators with deliberately varied geometry (and hence varied participation ratios).

# %%
attributes_table
# Out:
#                      Name  ID     Type
# 0                1__cross   1  Surface
# 9                  1__gap  11  Surface
# 10              2__padGap  12  Surface
# 13              substrate  13   Volume
# 14                    air  14   Volume
# 11           ground_plane  15  Surface
# 12              far_field  16  Surface
# 1                  2__pad   2  Surface
# 2           3__launch_pad   3  Surface
# 3           4__launch_pad   4  Surface
# 4   1__josephson_junction   5  Surface
# 5       3__feedline_port1   6  Surface
# 6       4__feedline_port2   7  Surface
# 7                5__trace   8  Surface
# 8                7__trace   9  Surface

# %%
# using attributes_table returned from meshing:

# ports
JJ_id = 5
feedline_port1_id = 6
feedline_port2_id = 7

# for post processing 
qubit_metal_id = 1 # also used for PEC BC
claw_metal_id = 2  # also used for PEC BC
qubit_gap_id = 11
claw_gap_id = 12

# mesh IDs for metals / PECs 
# for this simulation we can give every attribute that is not a port or JJ a PEC
PEC_surfaces = []
for ID in attributes_table.ID:
    ID = int(ID)
    if ID not in [substrate_id,airbox_id,JJ_id, feedline_port1_id,feedline_port2_id,qubit_gap_id,claw_gap_id]: # don't want our ports or volumnes to be PEC...
        PEC_surfaces.append(ID)


# assign the all these IDs to PEC
PECs = Boundaries.PEC(PEC_surfaces)

# define JJ
## ensure to give each port a different Index number, or Palace will raise an error.
LJ = 9.09*1e-09 # nH taken from 
JJ = Boundaries.LumpedPort(Index=1,Attributes=[JJ_id],Direction="+Y",L=LJ)

# define feedline ports with 50 Ohm termination  
fl_port1 = Boundaries.LumpedPort(Index=2,Attributes=[feedline_port1_id],Direction="+X",R=50) 
fl_port2 = Boundaries.LumpedPort(Index=3,Attributes=[feedline_port2_id],Direction="-X",R=50) 

# defining dielectric loss postprocessing --> we will not actually analyze these results today but to show how to prepare for interface participation analysis
eps_i, tandelta_i, t_i = 10, 0.002, 0.003
MA = Boundaries.Postprocessing_Dielectric(Index=1, Attributes=[qubit_metal_id,claw_metal_id], Type="MA", Thickness=t_i, Permittivity=eps_i, LossTan=tandelta_i)
MS = Boundaries.Postprocessing_Dielectric(Index=2, Attributes=[qubit_metal_id,claw_metal_id], Type="MS", Thickness=t_i, Permittivity=eps_i, LossTan=tandelta_i)
SA = Boundaries.Postprocessing_Dielectric(Index=3, Attributes=[qubit_gap_id,claw_gap_id], Type="SA", Thickness=t_i, Permittivity=eps_i, LossTan=tandelta_i)

# add Boundary conditions to our configuration file
BCs = [PECs,JJ,fl_port1,fl_port2] # boundary condition list for input into add_Boundaries()
PP_BCs = [MA,MS,SA]
eigenmode_config.add_Boundaries(BCs=BCs,Postprocessing=PP_BCs)

# %% [markdown]
# ## Add `config["Solver"]`
#
# Used to define the numerical parameters controlling the simulation.
#
# Below, we intentionally use relatively coarse solver settings to reduce compute time for the purposes of this tutorial. For higher-fidelity simulations, more stringent settings may be appropriate:
#
# | Eigenmode Parameter | Value |
# | :---: | :---: |
# | Tol | 1e-10 |
# | MaxIts | 100 |
#
# | Linear Solver Parameter | Value |
# | :---: | :---: |
# | Tol | 1e-10 |
# | MaxIts | 200 |
#
# In addition to the solver settings below, the finite element basis order can significantly impact simulation accuracy. For my own simulation I always keep order $\ge$ 2.
#
# > **Note:** Refined simulation parameters and higher-order basis orders will generally improve solution accuracy and convergence, but may significantly increase computational cost.

# %%
## eigenmode parameters
eigenmode_params = Solver.Eigenmode(Target = 2, # 
                                    Tol = 5e-4,
                                    N = 3,
                                    Save = 3)

## linear solver parameters
Linear_params = Solver.Linear(Type="Default",
                              KSPType = "Default",
                              Tol = 5e-4,
                              MaxIts = 10)

eigenmode_config.add_Solver(Simulation=eigenmode_params,
                            Order = 1, # basis order
                            Linear=Linear_params)

# %% [markdown]
# ## Save our configuration file

# %%
eigenmode_config.save_config(check_validity=True)
eigenmode_config.print_config()
# Out:
# {
#   "Problem": {
#     "Type": "Eigenmode",
#     "Verbose": 2,
#     "Output": "eigenmode_output"
#   },
#   "Model": {
#     "Mesh": "mesh/eigenmode_epr.msh",
#     "L0": 1e-06
#   },
#   "Domains": {
#     "Materials": [
#       {
#         "Attributes": [
#           13
#         ],
#         "Permeability": 1.0,
#         "Permittivity": 11.45,
#         "LossTan": 1e-07
#       },
#       {
#         "Attributes": [
#           14
#         ],
#         "Permeability": 1.0,
#         "Permittivity": 1.0,
#         "LossTan": 0.0
#       }
#     ]
#   },
#   "Boundaries": {
#     "PEC": {
#       "Attributes": [
#         1,
#         15,
#         16,
#         2,
#         3,
#         4,
#         8,
#         9
#       ]
#     },
#     "LumpedPort": [
#       {
#         "Index": 1,
#         "Attributes": [
#           5
#         ],
#         "Direction": "+Y",
#         "L": 9.09e-09
#       },
#       {
#         "Index": 2,
#         "Attributes": [
#           6
#         ],
#         "Direction": "+X",
#         "R": 50
#       },
#       {
#         "Index": 3,
#         "Attributes": [
#           7
#         ],
#         "Direction": "-X",
#         "R": 50
#       }
#     ],
#     "Postprocessing": {
#       "Dielectric": [
#         {
#           "Index": 1,
#           "Attributes": [
#             1,
#             2
#           ],
#           "Type": "MA",
#           "Thickness": 0.003,
#           "Permittivity": 10,
#           "LossTan": 0.002
#         },
#         {
#           "Index": 2,
#           "Attributes": [
#             1,
#             2
#           ],
#           "Type": "MS",
#           "Thickness": 0.003,
#           "Permittivity": 10,
#           "LossTan": 0.002
#         },
#         {
#           "Index": 3,
#           "Attributes": [
#             11,
#             12
#           ],
#           "Type": "SA",
#           "Thickness": 0.003,
#           "Permittivity": 10,
#           "LossTan": 0.002
#         }
#       ]
#     }
#   },
#   "Solver": {
#     "Order": 1,
#     "Device": "CPU",
#     "Eigenmode": {
#       "N": 3,
#       "Save": 3,
#       "Type": "Default",
#       "Target": 2,
#       "Tol": 0.0005
#     },
#     "Linear": {
#       "Type": "Default",
#       "KSPType": "Default",
#       "Tol": 0.0005,
#       "MaxIts": 10
#     }
#   }
# }

# %% [markdown]
# ## Run the eigenmode simulation of our transmon-resonator system

# %%
from pypalace import Simulation # used to run simulations and extract simulation results 
from pypalace.palace_env import get_palace_executable  # auto-find path_to_palace 
from qdw_workshop.palace import install_pypalace_runner, palace_cpu_count

install_pypalace_runner()

# %%
path_to_palace = get_palace_executable() # only works if you added palace to your path, if not use line below
# path_to_palace = /path/to/palace/bin/palace-<arch>.bin

# %% [markdown]
# ### Initialize our simulation object

# %%
eigenmode_simulation = Simulation(eigenmode_config,path_to_palace)

# %% [markdown]
# ### Run the simulation

# %%
mpi_processes = palace_cpu_count()
eigenmode_simulation.run(n=mpi_processes)
# Out:
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
#
# --> Warning!
# Output folder is not empty; program will overwrite content! (eigenmode_output)
# Git changeset ID: v0.13.0-509-g360de9ab
# Running with 4 MPI processes
# Device configuration: cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
# Added 26 elements in 1 iterations of local bisection for under-resolved interior boundaries
# Added 8372 duplicate vertices for interior boundaries in the mesh
# Added 24562 duplicate boundary elements for interior boundaries in the mesh
# Added 16433 boundary elements for material interfaces to the mesh
# Finished partitioning mesh into 4 subdomains
#
# Characteristic length and time scales:
#  L₀ = 3.970e-03 m, t₀ = 1.324e-02 ns
#
# Mesh curvature order: 1
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-1.985e-03, -2.300e-03, -5.000e-04) m
#  (Xmax, Ymax, Zmax) = (+1.985e-03, +6.115e-04, +5.000e-04) m
#
# Parallel Mesh Stats:
#
#                 minimum     average     maximum       total
#  vertices         11444       11506       11621       46026
#  edges            65445       66120       66436      264481
#  faces           101377      101978      102319      407913
#  elements         47346       47364       47380      189457
#  neighbors            3           3           3
#
#             minimum     maximum
#  h      0.000447982   0.0413333
#  kappa      1.03193     299.897
#
# Configuring Robin impedance BC for lumped ports at attributes:
#  5: Ls = 2.454e-09 H/sq, n = (+0.0,+0.0,+1.0)
#  6: Rs = 1.717e+02 Ω/sq, n = (+0.0,-0.0,+1.0)
#  7: Rs = 1.717e+02 Ω/sq, n = (+0.0,+0.0,+1.0)
#
# Configuring lumped port circuit properties:
#  Index = 1: L = 9.090e-09 H
#  Index = 2: R = 5.000e+01 Ω
#  Index = 3: R = 5.000e+01 Ω
#
# Configuring Dirichlet PEC BC at attributes:
#  1-4, 8-9, 15-16
#
# Assembling system matrices, number of global unknowns:
#  H1 (p = 1): 46026, ND (p = 1): 264481, RT (p = 1): 407913
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 6, Q = 4 (quadrature order = 2)
#
# Configuring SLEPc eigenvalue solver:
#  Scaling γ = 2.092e+03, δ = 7.672e-07
#  Configuring divergence-free projection
#  Using random starting vector
#  Shift-and-invert σ = 2.000e+00 GHz (1.664e-01)
#
# Assembling multigrid hierarchy:
#  Level 0 (p = 1): 264481 unknowns
#  Level 0 (auxiliary) (p = 1): 46026 unknowns
#
# #PETSc Option Table entries:
# -eps_monitor # (source: code)
# #End of PETSc Option Table entries
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 1.003937e+00
#  1 (restart 0) KSP residual norm 2.864570e-01
#  2 (restart 0) KSP residual norm 7.984882e-03
#  3 (restart 0) KSP residual norm 2.833007e-04
# GMRES solver converged in 3 iterations (avg. reduction factor: 6.559e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 5.351351e-01
#  1 (restart 0) KSP residual norm 2.265716e-01
#  2 (restart 0) KSP residual norm 3.560877e-03
#  3 (restart 0) KSP residual norm 1.489281e-03
#  4 (restart 0) KSP residual norm 3.790741e-06
# GMRES solver converged in 4 iterations (avg. reduction factor: 5.159e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 2.501658e+00
#  1 (restart 0) KSP residual norm 1.178647e+00
#  2 (restart 0) KSP residual norm 1.750794e-02
#  3 (restart 0) KSP residual norm 7.451124e-03
#  4 (restart 0) KSP residual norm 1.124120e-05
# GMRES solver converged in 4 iterations (avg. reduction factor: 4.604e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 1.800914e+00
#  1 (restart 0) KSP residual norm 1.468409e+00
#  2 (restart 0) KSP residual norm 7.829896e-03
#  3 (restart 0) KSP residual norm 4.173546e-03
#  4 (restart 0) KSP residual norm 7.002039e-06
# GMRES solver converged in 4 iterations (avg. reduction factor: 4.441e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 2.057500e+00
#  1 (restart 0) KSP residual norm 1.470564e+00
#  2 (restart 0) KSP residual norm 6.687129e-02
#  3 (restart 0) KSP residual norm 3.240119e-02
#  4 (restart 0) KSP residual norm 4.884450e-05
# GMRES solver converged in 4 iterations (avg. reduction factor: 6.980e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 2.347932e+00
#  1 (restart 0) KSP residual norm 1.720548e+00
#  2 (restart 0) KSP residual norm 8.201424e-02
#  3 (restart 0) KSP residual norm 3.526562e-02
#  4 (restart 0) KSP residual norm 5.247874e-05
# GMRES solver converged in 4 iterations (avg. reduction factor: 6.876e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 2.933476e+00
#  1 (restart 0) KSP residual norm 7.144350e-01
#  2 (restart 0) KSP residual norm 1.096789e-02
#  3 (restart 0) KSP residual norm 5.253977e-03
#  4 (restart 0) KSP residual norm 9.857114e-06
# GMRES solver converged in 4 iterations (avg. reduction factor: 4.281e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 4.819142e+00
#  1 (restart 0) KSP residual norm 2.082074e+00
#  2 (restart 0) KSP residual norm 2.412518e-02
#  3 (restart 0) KSP residual norm 1.177365e-02
#  4 (restart 0) KSP residual norm 2.034326e-05
# GMRES solver converged in 4 iterations (avg. reduction factor: 4.533e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 1.088986e+01
#  1 (restart 0) KSP residual norm 1.892801e+00
#  2 (restart 0) KSP residual norm 3.741186e-02
#  3 (restart 0) KSP residual norm 2.209490e-02
#  4 (restart 0) KSP residual norm 4.725373e-05
# GMRES solver converged in 4 iterations (avg. reduction factor: 4.564e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 4.893194e+01
#  1 (restart 0) KSP residual norm 3.204576e+00
#  2 (restart 0) KSP residual norm 1.289611e-01
#  3 (restart 0) KSP residual norm 6.413495e-02
#  4 (restart 0) KSP residual norm 1.127273e-04
# GMRES solver converged in 4 iterations (avg. reduction factor: 3.896e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 7.220995e+01
#  1 (restart 0) KSP residual norm 1.690888e+00
#  2 (restart 0) KSP residual norm 1.390283e-01
#  3 (restart 0) KSP residual norm 6.152033e-02
#  4 (restart 0) KSP residual norm 1.054718e-04
# GMRES solver converged in 4 iterations (avg. reduction factor: 3.476e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 4.753689e+02
#  1 (restart 0) KSP residual norm 6.445675e+00
#  2 (restart 0) KSP residual norm 4.398830e-02
# GMRES solver converged in 2 iterations (avg. reduction factor: 9.620e-03)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 1.415909e+03
#  1 (restart 0) KSP residual norm 1.124374e+01
#  2 (restart 0) KSP residual norm 6.890764e-02
# GMRES solver converged in 2 iterations (avg. reduction factor: 6.976e-03)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 9.795458e+02
#  1 (restart 0) KSP residual norm 6.765221e+00
#  2 (restart 0) KSP residual norm 5.058878e-02
# GMRES solver converged in 2 iterations (avg. reduction factor: 7.186e-03)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 4.177448e+02
#  1 (restart 0) KSP residual norm 3.608042e+00
#  2 (restart 0) KSP residual norm 2.286381e-02
# GMRES solver converged in 2 iterations (avg. reduction factor: 7.398e-03)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 8.373530e+02
#  1 (restart 0) KSP residual norm 1.987077e+01
#  2 (restart 0) KSP residual norm 1.316873e-01
# GMRES solver converged in 2 iterations (avg. reduction factor: 1.254e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 2.031976e+02
#  1 (restart 0) KSP residual norm 2.673342e+00
#  2 (restart 0) KSP residual norm 7.598299e-02
# GMRES solver converged in 2 iterations (avg. reduction factor: 1.934e-02)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 3.621806e+02
#  1 (restart 0) KSP residual norm 9.284794e+00
#  2 (restart 0) KSP residual norm 2.050494e-01
#  3 (restart 0) KSP residual norm 1.117065e-01
# GMRES solver converged in 3 iterations (avg. reduction factor: 6.756e-02)
#   1 EPS nconv=3 first unconverged value (error) -5.76013e-05+0.000428012i (2.04224431e-03)
#
#  Linear eigensolve converged (3 eigenpairs) due to CONVERGED_TOL; iterations 1
#  Total number of linear systems solved: 18
#  Total number of linear solver iterations: 58
#  Found 3 converged eigenvalues (first = -2.020e-07+4.464e-01i)
#
# Computing solution error estimates and performing postprocessing
#
# m,        Re{f} (GHz),        Im{f} (GHz),                  Q,      Error (Bkwd.),       Error (Abs.)
# 1,      +5.365383e+00,      +2.427139e-06,      +1.105290e+06,      +3.621967e-09,      +9.422965e-03
#  Wrote mode 1 to disk
# 2,      +5.989158e+00,      +2.774600e-03,      +1.079283e+03,      +6.182395e-10,      +1.608422e-03
#  Wrote mode 2 to disk
# 3,      +6.809279e+00,      -2.491917e-02,      +1.366282e+02,      +1.677767e-09,      +4.364906e-03
#  Wrote mode 3 to disk
#
# Completed 0 iterations of adaptive mesh refinement (AMR):
#  Indicator norm = 6.618e-01, global unknowns = 264481
#  Max. iterations = 0, tol. = 1.000e-02
#
# Elapsed Time Report (s)           Min.        Max.        Avg.
# ==============================================================
# Initialization                   0.082       0.085       0.083
#   Mesh Preprocessing             2.084       2.084       2.084
# Operator Construction            2.516       2.519       2.518
# Linear Solve                     4.682       4.687       4.684
#   Setup                          0.723       0.724       0.724
#   Preconditioner                 7.092       7.097       7.095
# Eigenvalue Solve                 1.857       1.858       1.858
# Div.-Free Projection            10.291      10.292      10.292
# Estimation                       0.171       0.173       0.172
#   Construction                   2.041       2.043       2.042
#   Solve                         12.122      12.123      12.122
# Postprocessing                   0.717       0.720       0.718
# Disk IO                          7.554       7.557       7.556
# --------------------------------------------------------------
# Total                           51.962      51.962      51.962

# %% [markdown]
# # Visualize the field distributions
#
# Visualizing the fields allows us to:
# * Identify different circuit modes (e.g., what mode corresponds to qubit versus the resonator).
# * Look for spurious modes, cross talk, or field non-uniformity that could point to potential places for design refinement.

# %%
# %matplotlib inline
eigenmode_simulation.plot_field(field="E",index=1) # plot magnitude of electric field [V/m]

# %%
eigenmode_simulation.plot_field(field="E",index=3) # plot magnitude of electric field [V/m]

# %% [markdown]
# the above field distributions confirm that the first mode corresponds to our qubit and the third mode corresponds to the resonator. The second mode looks deceivingly like the resonator mode as well but the field shape implies it's a spurious mode. This would probably be removed with the addition of airbridges.

# %% [markdown]
# # Extract simulation results
#
# This eigenmode simulation gives us a plethora of relevant data for superconducting circuits:
# * **Resonant frequencies**  $\rightarrow$ intrinsically returned from eigenmode sims.
# * **Resonator's $\kappa_\text{tot}$** $\rightarrow$ returned from the complex eigenmode frequency ($\kappa_\text{tot} = \kappa_\text{int} + \kappa_\text{ext}$)
# * **Resonator's $\kappa_\text{ext}$** $\rightarrow$ automatically returned if we define external feedline ports.
# * **Energy participation of the junction (EPR)** $\rightarrow$ automatically returned if we define a junction lumped port.
#
# pyPalace has some nice functionality to cleanly extract these simulation results.

# %%
# extract simulation results needed for EPR 
## eigenmode frequencies
fq = eigenmode_simulation.get_frequency_eigenmode(mode=1) # qubit frequency [Hz]
fr = eigenmode_simulation.get_frequency_eigenmode(mode=3) # resonator frequency [Hz]

## participation ratios
pq = eigenmode_simulation.get_portEPR(port_index=1,mode=1) # qubit participation
pr = eigenmode_simulation.get_portEPR(port_index=1,mode=3) # resonator participation

## normalize the ratios 
# not always necessary with Palace from my experience but my Mac Silicon Palace install returns unscaled values
pq = pq/(pq+pr)
pr = pr/(pq+pr)

## resonator photon decay rates (kappa_total, kappa_ext, kappa_int)
kappa_tot = eigenmode_simulation.get_kappa_eigenmode(mode=3)
kappa_ext = eigenmode_simulation.get_kappa_ext(mode=3,ports=[2,3])
kappa_int = kappa_tot - kappa_ext

# %% [markdown]
# # EPR Analysis
#
# An eigenmode simulation of a transmon-resonator system followed by EPR analysis enables us to extract almost every Hamiltonian parameter of interest. EPR is an especially useful quantum analysis technique since it is geometry agnostic. **But** eigenmode simulations are the most computationally expensive simulation type, especially as one moves to larger devices: solving a large system for many eigenvalues (which give the mode frequencies) and their associated eigenvectors (field distributions) is among the hardest tasks in numerical linear algebra ([Elkin et al., arXiv:2511.20774 (2025)](https://arxiv.org/abs/2511.20774), Secs. II C and IV A).
#
# ## Brief look at EPR
#
# Below is a brief look at EPR analysis. Quantum mechanically the participation $p_m$ of the junction in mode $m$ is given by [Minev et al. (2021)](https://doi.org/10.1038/s41534-021-00457-2):
#
# $$
# p_m = \frac{\langle\psi_m|\frac{1}{2}E_J\hat{\varphi}^2|\psi_m\rangle}{\langle\psi_m|\frac{1}{2}\hat{H}_\text{lin}|\psi_m\rangle}
# $$
#
# where $\hat{H}_\text{lin} = \hbar\omega_r\hat{a}^\dagger\hat{a} + \hbar\omega_q\hat{b}^\dagger\hat{b}$. Palace extracts the participations classically (see [here](https://awslabs.github.io/palace/stable/reference/#Energy-participation-ratios)).
#
# $$
# p_{mj} = \frac{L_j I_{mj}^2}{2\mathcal{E}_m^\text{elec}}
# $$
#
# where $p_{mj}$ is the participation of junction $j$ in mode $m$, $I_{mj}$ is the is the peak current of junction $j$ for mode $m$,   $\mathcal{E}_m^\text{elec}$ is the electric energy stored in mode $m$.
#
#
# ## Using participations for quantum analysis
#
# After extracting participations of the qubit and the resonator, we can use the following analytic equations to compute Hamiltonian parameters [Minev et al. (2021)](https://doi.org/10.1038/s41534-021-00457-2):
#
# qubit anharmonicity: $$\alpha = p_q^2\frac{\hbar\omega_q^2}{8E_J}$$
#
# qubit–resonator dispersive shift: $$\chi = p_qp_r\frac{\hbar\omega_q\omega_r}{4E_J}$$
#
# We can use the dispersive shift to calculate the qubit-resonator coupling strength [non-RWA] [Shanto et al. (2024)](https://doi.org/10.22331/q-2024-09-09-1465):
#
#
# $$
# g=\sqrt{\frac{\chi}{2\left(\frac{\alpha_q}{\Delta(\Delta-\alpha_q)}+\frac{\alpha_q}{\Sigma(\Sigma+\alpha_q)}\right)}}
# $$
#
#
# > For a more in-depth look at quantum analysis techniques, check out the **EM Quantum Analysis Techniques** workshop led by Alp Sipahigil (if you are attending QDW).

# %%
from pypalace.analysis import EPR

# %%
alpha = EPR.calculate_anharmonicity(pq, fq, LJ)
chi = EPR.calculate_dispersive_shift(pq, pr, fq, fr, LJ)
g = EPR.calculate_coupling_strength(fq, fr, alpha, chi)

# %% [markdown]
# We now have all the desired Hamiltonian parameters for a single transmon-resonator system:
#
# > $\kappa$ values are particularly sensitive to simulation paramters from my experience. To get reasonable values, we need finer mesh/AMR and better simulation parameters. The values below will probably be much too large since this is a quick simulation demo.

# %%
print("Hamiltonian parameters:")
print("=======================")
print("\nQubit parameters:")
print("-----------------------")
print(f"f_q = {fq/1e9:.2f} GHz")
print(f"alpha = {alpha/1e6:.2f} MHz")
print("\nResonator parameters:")
print("-----------------------")
print(f"f_r = {fr/1e9:.2f} GHz")
print(f"kappa_tot = {kappa_tot/1e6:.2f} MHz") 
print(f"kappa_ext = {kappa_ext/1e6:.2f} MHz")
print(f"kappa_int = {kappa_int/1e6:.2f} MHz")
print("\nCoupled parameters:")
print("-----------------------")
print(f"chi = {chi/1e6:.2f} MHz")
print(f"g = {g/1e6:.2f} MHz")

print("\nMesh resolution and simulation parameters were very coarse - these values have large uncertainties")
# Out:
# Hamiltonian parameters:
# =======================
#
# Qubit parameters:
# -----------------------
# f_q = 5.37 GHz
# alpha = -200.10 MHz
#
# Resonator parameters:
# -----------------------
# f_r = 6.81 GHz
# kappa_tot = 49.84 MHz
# kappa_ext = 15.45 MHz
# kappa_int = 34.39 MHz
#
# Coupled parameters:
# -----------------------
# chi = -0.28 MHz
# g = 40.19 MHz
#
# Mesh resolution and simulation parameters were very coarse - these values have large uncertainties

# %% [markdown]
# # Next tutorial: electrostatic simulation + LOM
#
# Continue with [`electrostatic_LOM.ipynb`](./electrostatic_LOM.ipynb) — electrostatic simulation of a grounded transmon with capacitance extraction and LOM analysis.
