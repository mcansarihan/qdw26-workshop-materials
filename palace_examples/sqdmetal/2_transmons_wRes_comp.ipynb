# %% [markdown]
# # 2 Transmons with resonator, Capacitance and qubit parameters computation

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
os.environ["PMIX_MCA_gds"]="hash"
os.environ['OMPI_MCA_btl'] = 'tcp,self'
os.environ['OMPI_MCA_rmaps_base_oversubscribe'] = '1'
import shutil

# Import useful packages
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs
from SQDMetal.Utilities.QUtilities import QUtilities
import matplotlib.pyplot as plt
from SQDMetal.Comps.Qubits import TransmonTaperedInsets
from SQDMetal.Comps.Capacitors import Smooth_CapacitorProngPin, Smooth_Capacitor_Semicircle
from SQDMetal.Comps.Resonators import ResonatorMeanderPinPin
from SQDMetal.Utilities.QubitDesigner import ResonatorHalfWave
from qiskit_metal.analyses import cpw_calculations
from SQDMetal.Utilities.Materials import Material
from SQDMetal.Utilities.CpwParams import CpwParams

### Qubit, resonator frequencies
qubit_freq = [4.5*1e9, 4.5*1e9]
res_freq_GHZ = qubit_freq[1] + 2.3 *1e9

# %% [markdown]
# ## Design

# %%
## Resonator design parameters
resonator = ResonatorHalfWave(res_freq_GHZ)

m = Material("siliconcryo")

# CPW parameters
cpw_width = 10e-6
cpw = CpwParams(m.permittivity, 500e-6)
cpw_gap = cpw.get_gap_from_width(cpw_width)

l_fullwave, _, _ = cpw_calculations.guided_wavelength(
                freq=resonator.f0,
                line_width=cpw_width,
                line_gap=cpw_gap,
                substrate_thickness=cpw.dielectric_thickness,
                film_thickness=200e-9,
            )
l_halfwave = l_fullwave / 2

print(f"Resonator length (f = {res_freq_GHZ} GHz): {l_halfwave *1e3:.2f} mm")
# Out:
# Resonator length (f = 6800000000.0 GHz): 8.96 mm

# %%
# %matplotlib inline

# Set up chip design as planar
design = designs.DesignPlanar({}, overwrite_enabled=True)

# Set up chip dimensions 
design.chips.main.size.size_x = '5.0mm'
design.chips.main.size.size_y = '2.0mm'
design.chips.main.size.size_z = '-280um'
design.chips.main.size.center_x = '0.0mm'
design.chips.main.size.center_y = '0mm'

# Resonator and feedline gap width (W) and center conductor width (S) 
design.variables['cpw_width'] = '10 um' #S
design.variables['cpw_gap'] = '6 um' #W 

#gui = MetalGUI(design)


########################################

TransmonTaperedInsets(design, 'Qubit1', options = Dict(pos_x = '-1.25mm', pos_y = '0.0mm', orientation = '0',
                                                       pocket_lower_tighten = '0.0um',pocket_height = '420um',chrgln_pin_x_offset="0um", chrgln_pin_y_offset="-10um"))


TransmonTaperedInsets(design, 'Qubit2', options = Dict(pos_x = '1.65mm', pos_y = '0.0mm', orientation = '0',
                                                       pocket_lower_tighten = '0.0um',pocket_height = '420um', chrgln_pin_x_offset="0um", chrgln_pin_y_offset="-10um"))


Smooth_Capacitor_Semicircle(design, 'Capacitor1',options=Dict(pin_inputs=Dict(start_pin=Dict(component=f'Qubit1',pin='top_right_pin')), orientation=180,
                                                              rect_width = '160um',rect_length = '80um', semi_radius = '60um',
                                                              fillet_radius = '5um',fillet_resolution = 20))

Smooth_Capacitor_Semicircle(design, 'Capacitor2',options=Dict(pin_inputs=Dict(start_pin=Dict(component=f'Qubit2',pin='top_left_pin')), orientation=0,
                                                              rect_width = '160um',rect_length = '80um', semi_radius = '60um',
                                                              fillet_radius = '5um',fillet_resolution = 20))

ResonatorMeanderPinPin(design, 'Resonator1', options = Dict(pin_inputs=Dict(start_pin=Dict(component='Capacitor1', pin='a'),
                                                            end_pin=Dict(component='Capacitor2', pin='a')),
                                            total_length = f"{l_halfwave*1e3}mm", start_left = False,
                                            trace_width = design.variables['cpw_width'], gap_width = design.variables['cpw_gap']))


#######################################

# Create GUI
#gui.rebuild()
design.rebuild()

# %%
QUtilities.plot_all_components(design)
plt.show()

# %% [markdown]
# ## Capacitance Simulation

# %%
from SQDMetal.PALACE.Capacitance_Simulation import PALACE_Capacitance_Simulation
import contextlib
import sys
from io import StringIO

#Eigenmode Simulation Options
user_defined_options = {
                "mesh_refinement": 0,                             #refines mesh in PALACE - essetially divides every mesh element in half
                "dielectric_material": "silicon",                  #choose dielectric material - 'silicon' or 'sapphire'
                "solver_order": 2,                                 #increasing solver order increases accuracy of simulation, but significantly increases sim time
                "solns_to_save": 3,                                #number of solutions to save for E-field visualization - ordered by the entries in the computed capacitance matrix
                "solver_tol": 1.0e-8,                              #error residual tolerance for iterative solver
                "solver_maxits": 200,                              #number of solver iterations
                "fillet_resolution":16,                            #number of vertices per quarter turn on a filleted path
                "palace_dir":shutil.which('palace'), 
                "num_cpus": 8,                                  #number of threads to use in PALACE simulation
                }

#Create the Palace capacitance simulation
cap_sim = PALACE_Capacitance_Simulation(name = '2_transmons_wRes_comp',                                      #name of simulation
                                        metal_design = design,                                      #feed in qiskit metal design
                                        sim_parent_directory = "",                                  #choose directory where mesh file, config file and HPC batch file will be saved
                                        mode = 'simPC',                                             #choose simulation mode 'HPC' or 'simPC'                                          
                                        meshing = 'GMSH',                                           #choose meshing 'GMSH' or 'COMSOL'
                                        user_options = user_defined_options,                        #provide options chosen above
                                        create_files = True)                                        #create mesh, config and HPC batch files

#Add metallic elements from layer 1 in design file
cap_sim.add_metallic(1)

#Add ground plane to simulations
cap_sim.add_ground_plane()

#Fine mesh the transmon cross qubit region
cap_sim.fine_mesh_components(['Qubit1', 'Qubit2'], min_size=12e-6, max_size=100e-6, taper_dist_min=10e-6, metals_only=False)

#Fine mesh resonator, launch pads and transmission line
cap_sim.fine_mesh_components(['Resonator1','Capacitor1','Capacitor2'], min_size=12e-6, max_size=120e-6, taper_dist_min=10e-6)

#This will prepare the mesh file and the config file
cap_sim.prepare_simulation()

capMat = cap_sim.run()
# Out:
# Error   : Gmsh has not been initialized
# Error   : Gmsh has not been initialized
# >> /home/abhis/spack/opt/spack/linux-zen2/openmpi-5.0.10-vb74eb34l4i3g3uvaizygx4sw4v4dr4i/bin/mpirun -n 8 /home/abhis/spack/opt/spack/linux-zen2/palace-0.16.0-5snwbjet4zabpqxhvkbyavuep7pe76at/bin/palace-x86_64.bin 2_transmons_wRes_comp.json
#
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
#
# --> Warning!
# Output folder is not empty; program will overwrite content! (outputFiles)
# Git changeset ID: 869ee5c
# Running with 8 MPI processes
# Device configuration: cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
# Added 1128 boundary elements for material interfaces to the mesh
# Finished partitioning mesh into 8 subdomains
#
# Characteristic length and time scales:
#  Lc = 6.000e-03 m, tc = 2.001e-02 ns
#
# Mesh curvature order: 1
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-3.000e-03, -1.200e-03, -2.800e-04) m
#  (Xmax, Ymax, Zmax) = (+3.000e-03, +1.200e-03, +2.800e-04) m
#
# Parallel Mesh Stats:
#
#                 minimum     average     maximum       total
#  vertices          4907        5296        5703       42372
#  edges            33716       34606       35837      276853
#  faces            57475       58055       59388      464441
#  elements         28584       28744       29253      229959
#  neighbors            2           3           5
#
#             minimum     maximum
#  h      0.000294181   0.0296792
#  kappa      1.06404     95.4728
#
# Estimated current per-rank memory usage is: Min. 48.0M, Max. 188.2M, Avg. 65.7M, Total 525.9M
# Estimated current per-node memory usage is: Min. 526.7M, Max. 526.7M, Avg. 526.7M, Total 526.7M
#
# Configuring Dirichlet BC at attributes:
#  9-14, 1-6
#
# Assembling system matrices, number of global unknowns:
#  H1 (p = 2): 319225, ND (p = 2): 1482588, RT (p = 2): 2083200
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 20, Q = 11 (quadrature order = 4)
#
# Assembling multigrid hierarchy:
#  Level 0 (p = 1): 42372 unknowns
#  Level 1 (p = 2): 319225 unknowns
#
# Computing electrostatic fields for 6 terminal boundaries
#
# It 1/6: Index = 1 (elapsed time = 1.43e-07 s)
#
#   Residual norms for PCG solve
#   0 KSP residual norm ||r||_B = 2.443375e+01
#   1 KSP residual norm ||r||_B = 2.080324e+00
#   2 KSP residual norm ||r||_B = 2.421083e-01
#   3 KSP residual norm ||r||_B = 3.922221e-02
#   4 KSP residual norm ||r||_B = 8.706068e-03
#   5 KSP residual norm ||r||_B = 2.113743e-03
#   6 KSP residual norm ||r||_B = 5.852416e-04
#   7 KSP residual norm ||r||_B = 1.609840e-04
#   8 KSP residual norm ||r||_B = 3.983669e-05
#   9 KSP residual norm ||r||_B = 1.053378e-05
#  10 KSP residual norm ||r||_B = 2.618546e-06
#  11 KSP residual norm ||r||_B = 6.664247e-07
# PCG solver converged in 11 iterations (avg. reduction factor: 1.713e-01)
#  Sol. ||V|| = 3.123847e+02 (||RHS|| = 1.780966e+02)
#  Field energy E = 1.035e-09 J
#
#  Wrote fields to disk (Paraview) for source 1
#  Updating solution error estimates
#
# It 2/6: Index = 2 (elapsed time = 2.11e+01 s)
#
#   Residual norms for PCG solve
#   0 KSP residual norm ||r||_B = 5.879160e+00
#   1 KSP residual norm ||r||_B = 7.029342e-01
#   2 KSP residual norm ||r||_B = 1.380971e-01
#   3 KSP residual norm ||r||_B = 3.277348e-02
#   4 KSP residual norm ||r||_B = 7.435407e-03
#   5 KSP residual norm ||r||_B = 1.785181e-03
#   6 KSP residual norm ||r||_B = 3.707812e-04
#   7 KSP residual norm ||r||_B = 7.721613e-05
#   8 KSP residual norm ||r||_B = 1.865211e-05
#   9 KSP residual norm ||r||_B = 3.508397e-06
#  10 KSP residual norm ||r||_B = 7.990197e-07
#  11 KSP residual norm ||r||_B = 1.554008e-07
# PCG solver converged in 11 iterations (avg. reduction factor: 1.646e-01)
#  Sol. ||V|| = 1.233231e+02 (||RHS|| = 6.455322e+01)
#  Field energy E = 3.554e-11 J
#
#  Wrote fields to disk (Paraview) for source 2
#  Updating solution error estimates
#
# It 3/6: Index = 3 (elapsed time = 5.12e+01 s)
#
#   Residual norms for PCG solve
#   0 KSP residual norm ||r||_B = 5.894604e+00
#   1 KSP residual norm ||r||_B = 6.697011e-01
#   2 KSP residual norm ||r||_B = 1.194341e-01
#   3 KSP residual norm ||r||_B = 2.315271e-02
#   4 KSP residual norm ||r||_B = 4.569368e-03
#   5 KSP residual norm ||r||_B = 1.028727e-03
#   6 KSP residual norm ||r||_B = 2.612589e-04
#   7 KSP residual norm ||r||_B = 5.556641e-05
#   8 KSP residual norm ||r||_B = 1.183972e-05
#   9 KSP residual norm ||r||_B = 1.909511e-06
#  10 KSP residual norm ||r||_B = 3.372145e-07
# PCG solver converged in 10 iterations (avg. reduction factor: 1.486e-01)
#  Sol. ||V|| = 1.240622e+02 (||RHS|| = 6.400845e+01)
#  Field energy E = 3.407e-11 J
#
#  Wrote fields to disk (Paraview) for source 3
#  Updating solution error estimates
#
# It 4/6: Index = 4 (elapsed time = 8.27e+01 s)
#
#   Residual norms for PCG solve
#   0 KSP residual norm ||r||_B = 8.592505e+00
#   1 KSP residual norm ||r||_B = 9.089638e-01
#   2 KSP residual norm ||r||_B = 9.679237e-02
#   3 KSP residual norm ||r||_B = 1.957763e-02
#   4 KSP residual norm ||r||_B = 4.470050e-03
#   5 KSP residual norm ||r||_B = 9.150053e-04
#   6 KSP residual norm ||r||_B = 2.139583e-04
#   7 KSP residual norm ||r||_B = 3.925325e-05
#   8 KSP residual norm ||r||_B = 7.870672e-06
#   9 KSP residual norm ||r||_B = 1.727050e-06
#  10 KSP residual norm ||r||_B = 3.804240e-07
# PCG solver converged in 10 iterations (avg. reduction factor: 1.435e-01)
#  Sol. ||V|| = 1.467797e+02 (||RHS|| = 1.026357e+02)
#  Field energy E = 2.947e-10 J
#  Updating solution error estimates
#
# It 5/6: Index = 5 (elapsed time = 1.07e+02 s)
#
#   Residual norms for PCG solve
#   0 KSP residual norm ||r||_B = 5.894986e+00
#   1 KSP residual norm ||r||_B = 6.810283e-01
#   2 KSP residual norm ||r||_B = 1.387234e-01
#   3 KSP residual norm ||r||_B = 3.255887e-02
#   4 KSP residual norm ||r||_B = 8.682702e-03
#   5 KSP residual norm ||r||_B = 2.411939e-03
#   6 KSP residual norm ||r||_B = 5.793623e-04
#   7 KSP residual norm ||r||_B = 1.255182e-04
#   8 KSP residual norm ||r||_B = 2.805876e-05
#   9 KSP residual norm ||r||_B = 5.932451e-06
#  10 KSP residual norm ||r||_B = 1.562770e-06
#  11 KSP residual norm ||r||_B = 3.671404e-07
# PCG solver converged in 11 iterations (avg. reduction factor: 1.780e-01)
#  Sol. ||V|| = 1.234777e+02 (||RHS|| = 6.455304e+01)
#  Field energy E = 3.550e-11 J
#  Updating solution error estimates
#
# It 6/6: Index = 6 (elapsed time = 1.32e+02 s)
#
#   Residual norms for PCG solve
#   0 KSP residual norm ||r||_B = 5.932546e+00
#   1 KSP residual norm ||r||_B = 6.774580e-01
#   2 KSP residual norm ||r||_B = 1.343369e-01
#   3 KSP residual norm ||r||_B = 3.447709e-02
#   4 KSP residual norm ||r||_B = 9.656192e-03
#   5 KSP residual norm ||r||_B = 3.095327e-03
#   6 KSP residual norm ||r||_B = 7.053457e-04
#   7 KSP residual norm ||r||_B = 1.415973e-04
#   8 KSP residual norm ||r||_B = 3.062955e-05
#   9 KSP residual norm ||r||_B = 5.489937e-06
#  10 KSP residual norm ||r||_B = 1.020782e-06
#  11 KSP residual norm ||r||_B = 1.853839e-07
# PCG solver converged in 11 iterations (avg. reduction factor: 1.674e-01)
#  Sol. ||V|| = 1.244949e+02 (||RHS|| = 6.407143e+01)
#  Field energy E = 3.409e-11 J
#  Updating solution error estimates
#
# Completed 0 iterations of adaptive mesh refinement (AMR):
#  Indicator norm = 4.243e-01, global unknowns = 319225
#  Max. iterations = 0, tol. = 1.000e-02
#
# Estimated peak per-rank memory usage is: Min. 373.0M, Max. 383.8M, Avg. 376.0M, Total 2.9G
# Estimated peak per-node memory usage is: Min. 2.9G, Max. 2.9G, Avg. 2.9G, Total 2.9G
#
# Elapsed Time Report (s)           Min.        Max.        Avg.
# ==============================================================
# Initialization                   0.231       0.243       0.237
#   Mesh Preprocessing             3.802       3.802       3.802
# Operator Construction            0.730       0.965       0.813
# Linear Solve                     2.261       2.747       2.493
#   Setup                          3.624       3.625       3.624
#   Preconditioner                18.778      19.955      19.513
#   Coarse Solve                   0.470       1.209       0.717
# Estimation                       0.200       0.444       0.350
#   Construction                   6.268       6.291       6.282
#   Solve                        100.517     100.521     100.520
# Postprocessing                   7.198       7.229       7.210
#   Paraview                      22.707      22.710      22.709
# Disk IO                          1.154       1.162       1.159
# --------------------------------------------------------------
# Total                          169.443     169.444     169.444
#
# Error in plotting: 'Data array (V) not present in this dataset.'

# %%
#Display the indices of the conductors to match with capacitance matrix - it will be automatically generated with the output anyway
cap_sim.display_conductor_indices()
plt.show()

# %%
# Gives qubit parameters
results = cap_sim.calc_params_2_floating_transmons(print_all_capacitances=True,  
                                            qubit_freq=(qubit_freq),
                                            res = resonator
                                            )

###
# Out:
# Capacitance Results
# --------------------
# C1-Ground        =     73.496 fF
# C2-Ground        =     79.648 fF
# C3-Ground        =     73.432 fF
# C4-Ground        =     79.697 fF
# CQ1              =     78.830 fF
# CQ2              =     78.836 fF
# Cg1              =      7.191 fF
# Cg2              =      7.130 fF
# C_r              =   1446.211 fF
# C1_prime         =     85.986 fF
# C2_prime         =     85.931 fF
# C_r_prime        =   1459.340 fF
# Cg1_prime        =   8728.415 fF
# Cg2_prime        =   8798.020 fF
#
# Readout Resonator
# -------------------
# f_res            =      6.800 GHz
# L_res            =    745.009 pH
# C_res            =    735.294 fF
# Circuit Parameters
# -------------------
# f_qubit1         =      4.500 GHz
# f_qubit2         =      4.500 GHz
# E_C1             =    225.272 MHz
# E_C2             =    225.417 MHz
# E_Cc             =      0.184 MHz
# g1               =     83.500 MHz
# g2               =     82.793 MHz
#
# Target Junction Parameters
#  (for f_qubit1 = 4.5 GHz)
# --------------------------
# E_J1             =     12.390 GHz
# L_J1             =     13.193 nH
# E_J1/E_C1        =     54.998
#
# Target Junction Parameters
#  (for f_qubit2 = 4.5 GHz)
# --------------------------
# E_J2             =     12.382 GHz
# L_J2             =     13.201 nH
# E_J2/E_C2        =     54.931
#
# Q1-Q2 g12        =      0.006 GHz
# Q1-res g1        =    304.453 MHz
# Q2-res g2        =    301.952 MHz
# Q1 freq (uncoupled) =      4.500 GHz
# Q2 freq (uncoupled) =      4.500 GHz
# Res freq (uncoupled) =     30.328 GHz
# Z on/off ratio   =      1.188

# %%
print('Res_ground: ',capMat[0,3]*1e15, 'fF')
print('Pad1 to pad2: ',capMat[1,2]*1e15, 'fF')
print('Res to pad1: ',capMat[1,3]*1e15, 'fF')
print('Res to pad2: ',capMat[2,3]*1e15, 'fF')
# Out:
# Res_ground:  -1446.211368226 fF
# Pad1 to pad2:  -35.62766645933 fF
# Res to pad1:  -17.81645953715 fF
# Res to pad2:  -2.350359660315 fF

# %%
resonator.get_res_inductance()
# Out:
# 7.450087032524837e-10
